# %% [markdown]
# # Parse JDs, extract skills

# %%
import os
import re
import json
from pprint import pprint
from bs4 import BeautifulSoup
from bs4.element import Comment

import nltk
from nltk import word_tokenize          
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from nltk.chunk import conlltags2tree, tree2conlltags
from nltk import word_tokenize, pos_tag, ne_chunk
from nltk.corpus import stopwords
from nltk import RegexpTokenizer

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

import gensim
from pprint import pprint

import codecs
import os
import time

from stop_words import get_stop_words

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('words')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /Users/goodgame/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/goodgame/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package words to /Users/goodgame/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/goodgame/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/goodgame/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/goodgame/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import boto3
s3 = boto3.resource('s3')

# %%
# Raghu's code to pull down jobs
BUCKET_NAME = 'tech-salary-project'

# %%
# %%time

bucket = s3.Bucket(BUCKET_NAME)
all_job_titles = []
all_job_ids = []
all_summaries = []
for o in bucket.objects.all():
    if o.key.startswith('salaries'):
        continue
    
    object = bucket.Object(o.key)
    try :
        lines = object.get()['Body'].read().decode('utf-8').splitlines()
        for line in lines:
            d = json.loads(line)
            
            title = d['title']
            jid = d['id']
            summary = d['summary']
            
            all_job_ids.append(jid)
            all_job_titles.append(title)
            all_summaries.append(summary)
    except Exception as e:
        continue
# Out:
# CPU times: user 13.3 s, sys: 1.5 s, total: 14.8 s
# Wall time: 7min 10s

# %%
print('Number of all job titles:', len(all_job_titles))
uniq_job_titles = set(all_job_titles)
print('Number of unique job titles:', len(uniq_job_titles))

print('Number of all job ids:', len(all_job_ids))
uniq_job_ids = set(all_job_ids)
print('Number of unique job ids:', len(uniq_job_ids))

uniq_job_ids = set(all_job_ids)
print('Number of unique job ids:', len(uniq_job_ids))

print('\nNumber of summaries:',len(all_summaries))
unique_summaries = set(all_summaries)
print('Number of unique summaries:', len(unique_summaries))
# Out:
# Number of all job titles: 41777
# Number of unique job titles: 21917
# Number of all job ids: 41777
# Number of unique job ids: 39692
# Number of unique job ids: 39692
#
# Number of summaries: 41777
# Number of unique summaries: 39300

# %% [markdown]
# ## Use BS4 to convert the 'summary' field HTML into visible text, and load the files into memory

# %%
def tag_visible(element):
    if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
        return False
    if isinstance(element, Comment):
        return False
    return True

def make_text(text):
    soup = BeautifulSoup(text, "html5lib")
    texts = soup.findAll(text=True)
    visible_texts = filter(tag_visible, texts)
    return u" ".join(t.strip() for t in visible_texts)

# %%
# %%time
texts = []

for item in unique_summaries:
    texts.append(make_text(item))
# Out:
# CPU times: user 4min 26s, sys: 771 ms, total: 4min 26s
# Wall time: 4min 27s

# %%
# Write locally

for idx, text in enumerate(texts):
    title = all_job_titles[idx].replace(' ', '_').replace('/','_').replace('.','')
    job_id = str(all_job_ids[idx])
    doc_title = '/Users/goodgame/Desktop/texts/'+title+'_'+job_id+'.txt'
    with open(doc_title,'w+') as outfile:
        outfile.write(text)

# %%
print(all_job_titles[4].replace(' ', '_').replace('/','_'))
# Out:
# Specialist,_IT_App_Development_-_Application_Developer_(Java)

# %% [markdown]
# ## Extract noun phrases

# %%
stopwords = stopwords.words('english')
lemmatizer = nltk.WordNetLemmatizer()

# %%
def leaves(tree):
    """Finds NP (nounphrase) leaf nodes of a chunk tree."""
    for subtree in tree.subtrees(filter = lambda t: t.label()=='NP'):
        yield subtree.leaves()

def normalise(word):
    word = word.lower().replace('/','').replace('-','').replace('•','')
    # word = stemmer.stem_word(word) #if we consider stemmer then results comes with stemmed word, but in this case word will not match with comment
    word = lemmatizer.lemmatize(word)
    return word

def acceptable_word(word):
    """Checks conditions for acceptable word: length, stopword. We can increase the length if we want to consider large phrase"""
    accepted = bool(2 <= len(word) <= 40
        and word.lower() not in stopwords)
    return accepted


def get_terms(tree):
    for leaf in leaves(tree):
        term = [ normalise(w) for w,t in leaf if acceptable_word(w) ]
        yield term

# %%
# combine functions above
def noun_phrases(text):
    tokenizer = RegexpTokenizer('\w+|\$[\d\.]+|\S+')    
    lemmatizer = nltk.WordNetLemmatizer()
    stemmer = nltk.stem.porter.PorterStemmer()
    grammar = r"""
        NBAR:
            {<NN.*|JJ>*<NN.*>}  # Nouns and Adjectives, terminated with Nouns

        NP:
            {<NBAR>}
            {<NBAR><IN><NBAR>}  # Above, connected with in/of/etc...
    """
    chunker = nltk.RegexpParser(grammar)
    toks = tokenizer.tokenize(text)
    postoks = nltk.tag.pos_tag(toks)
    tree = chunker.parse(postoks)
    terms = get_terms(tree)
    bad_words = ['opportunity', 'ideal candidate', 'team', 'year', 'knowledge','experience']
    clean_terms = []
    
    for term in terms:
        term = ' '.join(term).replace('\n','').replace(',','').replace('(','')
        term = term.replace(')','')
        term = term.strip()
        if term not in bad_words:
            clean_terms.append(term)
    return clean_terms

# %%
print(len(texts))
# Out:
# 39300

# %%
# %%time
parsed_dataset = []

def parse_input_docs(doc):
    return ' '.join(noun_phrases(doc))

for item in texts:
    parsed_dataset.append(parse_input_docs(item))
print(len(parsed_dataset))
# Out:
# 39300
# CPU times: user 17min 13s, sys: 5.33 s, total: 17min 18s
# Wall time: 17min 21s

# %%
print(parsed_dataset[234])
# Out:
# make .tv make .tv provider cloud based live video acquisition management solution live video cloud “lvc” platform think video router switcher cloud company germany where development team headquarter seattle company unmatched solution top medium entertainment technology company esl mtv viacom mlb bamtech fox sport brasil swiss broadcasting corp srf. make .tv’s live video cloud content programmer service provider field news sport esports entertainment bring demand video screen source mobile video traditional camera .tv's investor microsoft venture voyager capital vulcan capital agile flat hierarchy lot freedom ownership regard self organization selection tool responsibility due distributed organization office seattle usa cologne germany satellite office los angeles remote location place beautiful place structure mistake "startup quick thing information www .make.tv [http:www.make.tv] responsibility implementation lvc backend service availability latency scalability make .tv’s service solve problem critical service automation problem recurrence influence design architecture large scale system qualification working proficiency communication skill english proficient knowledge linux server system b degree computer science technical field equivalent practical experience proficient go skill experience aws google cloud microsoft azure  ++ java python grpc docker kubernetes experience large scale system resilience pattern understanding process thread concurrency issue lock linux performance monitoring strace et al strong problem skill understanding algorithm complexity analysis expertise microservice architecture job offer colleague long term experience environment learning development task modern technology procedure freedom improvement method term job type: full time employment permanent place work job please application with cv job reference salary expectation start date make .tv day

# %% [markdown]
# We'll clearly need a better way to capture certain tech skills (C and C++ are cut off, etc.), but it's not bad for now.

# %% [markdown]
# ### Transform POS vectors into TF-IDF space.
# The terms should be more useful than the terms from the entire document.

# %%
stop_words = get_stop_words('en')

# %%
# %%time
# TF-IDF transformation in sklearn

pos_vect = TfidfVectorizer(stop_words=stop_words, ngram_range=(1,2), analyzer='word')  
pos_tfidf = pos_vect.fit_transform(texts)
print("\n Here are the dimensions of our two-gram dataset: \n", pos_tfidf.shape, "\n")
# Out:
#  Here are the dimensions of our two-gram dataset:
#  (39300, 2070759)
#
# CPU times: user 54 s, sys: 1.64 s, total: 55.6 s
# Wall time: 56 s

# %% [markdown]
# ### Clustering using Kmeans

# %%
# %%time
true_k = 30
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(pos_tfidf)
# Out:
# CPU times: user 16min 15s, sys: 50.5 s, total: 17min 5s
# Wall time: 17min 11s

# %%
# Pickling the model to avoid waiting another 30 min
import pickle
filename = 'kmeans_100_model.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
# !ls -lah kmeans_100_model.sav
# Out:
# -rw-r--r--  1 goodgame  staff   474M Mar 20 21:26 kmeans_100_model.sav

# %% [markdown]
# _This model is huge._

# %%
# Reload from disk, to be sure it works
loaded_model = pickle.load(open('kmeans_100_model.sav', 'rb'))

# %%
print("Top terms per cluster:")
order_centroids = loaded_model.cluster_centers_.argsort()[:, ::-1]
terms = pos_vect.get_feature_names()
for i in range(true_k):
    print("\n\nCluster %d:" % i, "\n")
    for ind in order_centroids[i, :40]:
        print(' %s' % terms[ind])
# Out:
# Top terms per cluster:
#
#
# Cluster 0:
#
#  experience
#  job
#  required
#  skills
#  software
#  data
#  work
#  will
#  management
#  must
#  time
#  years
#  00
#  support
#  team
#  project
#  development
#  type
#  full
#  knowledge
#  customer
#  technical
#  job type
#  full time
#  ability
#  days
#  systems
#  services
#  business
#  company
#  position
#  ago
#  year
#  days ago
#  client
#  quality
#  service
#  requirements
#  strong
#  education
#
#
# Cluster 1:
#
#  data
#  business
#  analyst
#  analysis
#  experience
#  reporting
#  data analyst
#  analytics
#  reports
#  skills
#  ability
#  work
#  management
#  sql
#  will
#  information
#  statistical
#  data analysis
#  excel
#  required
#  analytical
#  support
#  health
#  team
#  strong
#  knowledge
#  insights
#  requirements
#  quality
#  job
#  tools
#  years
#  systems
#  research
#  analyze
#  including
#  project
#  processes
#  related
#  sources
#
#
# Cluster 2:
#
#  amazon
#  experience
#  amazon com
#  software
#  technical
#  will
#  aws
#  development
#  alexa
#  com
#  basic qualifications
#  qualifications
#  team
#  software development
#  computer
#  services
#  systems
#  preferred qualifications
#  basic
#  computer science
#  science
#  design
#  building
#  customers
#  veteran gender
#  distributed
#  engineering
#  echo
#  minority
#  female
#  female disability
#  employer minority
#  product
#  scale
#  identity sexual
#  minority female
#  engineers
#  data
#  lab126
#  high
#
#
# Cluster 3:
#
#  test
#  testing
#  automation
#  experience
#  qa
#  software
#  quality
#  automated
#  test cases
#  cases
#  test automation
#  development
#  tests
#  tools
#  test plans
#  team
#  quality assurance
#  work
#  assurance
#  engineer
#  selenium
#  will
#  skills
#  plans
#  product
#  scripts
#  manual
#  web
#  years
#  experience testing
#  automated test
#  knowledge
#  functional
#  ability
#  execute
#  agile
#  strong
#  requirements
#  defects
#  regression
#
#
# Cluster 4:
#
#  facebook
#  people
#  together
#  closer together
#  build community
#  closer
#  people around
#  world
#  build
#  re
#  around world
#  menlo park
#  ways
#  menlo
#  community
#  bring
#  park
#  product
#  around
#  experience
#  facebook mission
#  family apps
#  people facebook
#  power build
#  world closer
#  community bring
#  reach people
#  facebook builders
#  matters helps
#  world gives
#  connects billions
#  gives ways
#  building different
#  heart global
#  iterating solving
#  builders heart
#  people power
#  business expand
#  helps bring
#  ways together
#
#
# Cluster 5:
#
#  sales
#  customer
#  customers
#  territory
#  technical
#  technical sales
#  business
#  products
#  accounts
#  industrial
#  required
#  experience
#  sales engineer
#  company
#  will
#  job
#  product
#  training
#  account
#  relationships
#  skills
#  equipment
#  travel
#  new
#  selling
#  market
#  service
#  assigned
#  sales experience
#  ability
#  position
#  industry
#  opportunities
#  work
#  mechanical
#  time
#  management
#  engineering
#  manufacturing
#  support
#
#
# Cluster 6:
#
#  experience
#  status
#  software
#  employment
#  will
#  protected
#  development
#  gender
#  work
#  disability
#  national
#  race
#  origin
#  applicants
#  data
#  religion
#  team
#  color
#  national origin
#  veteran
#  equal
#  regard
#  without regard
#  opportunity
#  sexual
#  sexual orientation
#  veteran status
#  without
#  orientation
#  identity
#  qualified
#  race color
#  color religion
#  sex
#  design
#  gender identity
#  regard race
#  systems
#  skills
#  age
#
#
# Cluster 7:
#
#  experience
#  software
#  development
#  web
#  design
#  applications
#  net
#  team
#  work
#  application
#  skills
#  code
#  technical
#  years
#  software development
#  javascript
#  technologies
#  will
#  solutions
#  java
#  sql
#  knowledge
#  services
#  developer
#  agile
#  using
#  business
#  systems
#  requirements
#  required
#  ability
#  strong
#  server
#  working
#  developing
#  testing
#  environment
#  new
#  job
#  programming
#
#
# Cluster 8:
#
#  data
#  learning
#  machine learning
#  machine
#  experience
#  data science
#  models
#  scientist
#  data scientist
#  science
#  statistical
#  analytics
#  algorithms
#  statistics
#  predictive
#  modeling
#  techniques
#  business
#  will
#  analysis
#  python
#  team
#  work
#  deep learning
#  research
#  mining
#  deep
#  large
#  skills
#  data mining
#  spark
#  big data
#  big
#  advanced
#  solutions
#  using
#  problems
#  insights
#  quantitative
#  scientists
#
#
# Cluster 9:
#
#  product
#  business
#  management
#  experience
#  manager
#  product manager
#  products
#  project
#  development
#  teams
#  customer
#  market
#  team
#  product management
#  will
#  work
#  ability
#  strategy
#  technical
#  marketing
#  skills
#  requirements
#  drive
#  new
#  manage
#  roadmap
#  functional
#  engineering
#  cross
#  customers
#  product development
#  stakeholders
#  program
#  user
#  strong
#  cross functional
#  data
#  sales
#  software
#  across
#
#
# Cluster 10:
#
#  apple
#  key qualifications
#  experience
#  software
#  ios
#  apple 30
#  team
#  key
#  will
#  education bs
#  description
#  macos
#  additional requirements
#  skills
#  siri
#  education
#  data
#  development
#  products
#  teams
#  strong
#  engineering
#  test
#  features
#  technologies
#  qualifications
#  systems
#  excellent
#  looking
#  quality
#  design
#  itunes
#  computer
#  work
#  programming
#  bs
#  new
#  testing
#  equivalent
#  experience apple
#
#
# Cluster 11:
#
#  product
#  marketing
#  sales
#  market
#  product marketing
#  products
#  management
#  business
#  customer
#  strategy
#  positioning
#  experience
#  manager
#  product management
#  develop
#  will
#  messaging
#  marketing manager
#  new
#  strategies
#  ability
#  content
#  pricing
#  development
#  skills
#  competitive
#  drive
#  go market
#  customers
#  product line
#  launch
#  work
#  including
#  line
#  product manager
#  cross
#  plans
#  teams
#  support
#  key
#
#
# Cluster 12:
#
#  booz
#  booz allen
#  allen
#  allen hamilton
#  hamilton
#  clients solve
#  consulting
#  clearance
#  firm
#  systems delivery
#  results endure
#  problems side
#  endure proud
#  capabilities booz
#  globe booz
#  integrating full
#  governments profits
#  hamilton forefront
#  today firm
#  allen committed
#  forefront strategy
#  one firm
#  profits across
#  allen one
#  missions booz
#  allen partners
#  technology 100
#  partners public
#  range consulting
#  delivery cybersecurity
#  challenges combination
#  achieve missions
#  side help
#  consulting analytics
#  consulting capabilities
#  engineering innovation
#  cybersecurity engineering
#  combination consulting
#  analytics mission
#  innovation expertise
#
#
# Cluster 13:
#
#  contract
#  hire
#  markets
#  workbridge associates
#  workbridge
#  offer
#  experience
#  basis now
#  offer sponsorship
#  future position
#  time basis
#  states full
#  position offer
#  motion recruitment
#  paired deep
#  tech skill
#  markets results
#  hire across
#  record candidates
#  results exemplary
#  sets paired
#  recruitment network
#  today highest
#  local technology
#  expertise today
#  highest demand
#  solutions contract
#  demand tech
#  part motion
#  exemplary track
#  major north
#  markets unique
#  american markets
#  knowledge local
#  network provides
#  unique expertise
#  networks knowledge
#  candidates clients
#  provides staffing
#  currently authorized
#
#
# Cluster 14:
#
#  ux
#  design
#  ui
#  designer
#  user
#  ui ux
#  experience
#  ux designer
#  ux ui
#  visual
#  mobile
#  web
#  interaction
#  wireframes
#  product
#  designs
#  graphic
#  work
#  user experience
#  visual design
#  ui designer
#  creative
#  sketch
#  ux design
#  flows
#  adobe
#  team
#  prototypes
#  photoshop
#  will
#  portfolio
#  create
#  illustrator
#  skills
#  digital
#  interface
#  interaction design
#  prototyping
#  experiences
#  ability
#
#
# Cluster 15:
#
#  design
#  user
#  ux
#  experience
#  designer
#  research
#  interaction
#  user experience
#  product
#  usability
#  ux designer
#  wireframes
#  experiences
#  work
#  prototypes
#  visual
#  user research
#  centered
#  user centered
#  team
#  designs
#  designers
#  interaction design
#  centered design
#  mobile
#  will
#  prototyping
#  create
#  ability
#  visual design
#  sketch
#  ux design
#  portfolio
#  web
#  digital
#  flows
#  human
#  business
#  skills
#  ui
#
#
# Cluster 16:
#
#  devops
#  experience
#  cloud
#  infrastructure
#  aws
#  tools
#  automation
#  deployment
#  devops engineer
#  continuous
#  configuration
#  systems
#  build
#  chef
#  jenkins
#  management
#  linux
#  puppet
#  release
#  docker
#  development
#  ansible
#  monitoring
#  ci
#  software
#  security
#  engineer
#  scripting
#  environments
#  services
#  configuration management
#  continuous integration
#  will
#  team
#  years
#  work
#  cd
#  integration
#  knowledge
#  production
#
#
# Cluster 17:
#
#  software
#  experience
#  development
#  systems
#  embedded
#  engineering
#  design
#  system
#  security
#  software development
#  clearance
#  hardware
#  test
#  required
#  requirements
#  will
#  computer
#  work
#  skills
#  team
#  years
#  support
#  technical
#  programming
#  linux
#  knowledge
#  testing
#  solutions
#  must
#  government
#  control
#  level
#  engineer
#  develop
#  degree
#  developing
#  position
#  data
#  applications
#  related
#
#
# Cluster 18:
#
#  experience
#  team
#  software
#  work
#  re
#  data
#  will
#  ll
#  build
#  building
#  new
#  product
#  platform
#  development
#  code
#  design
#  world
#  people
#  engineering
#  company
#  engineers
#  mobile
#  help
#  us
#  web
#  systems
#  working
#  technologies
#  technology
#  looking
#  make
#  can
#  end
#  like
#  cloud
#  engineer
#  services
#  one
#  best
#  products
#
#
# Cluster 19:
#
#  chase
#  jpmorgan
#  jpmorgan chase
#  technologists
#  technology
#  chase co
#  re
#  world
#  global
#  ll
#  financial
#  investment
#  co
#  development
#  team technologists
#  solutions
#  team
#  payments
#  work jpmorgan
#  banking
#  innovative solutions
#  hubs worldwide
#  institution re
#  deploy everything
#  innovations electronic
#  14 technology
#  well innovations
#  everything enterprise
#  biggest tech
#  employee re
#  technology hubs
#  companies 14
#  re integral
#  initiatives big
#  also change
#  thrives diversity
#  encourage professional
#  industry also
#  transform financial
#  skills every
#
#
# Cluster 20:
#
#  pdf
#  abb
#  gov
#  bose
#  dol
#  agilent
#  gov ofccp
#  ofccp
#  www dol
#  dol gov
#  fis
#  grubhub
#  ofccp regs
#  compliance posters
#  regs compliance
#  regs
#  posters
#  poster
#  posters pdf
#  http
#  suntrust
#  ofccp_eeo_supplement_final_jrf_qa_508c
#  ofccp_eeo_supplement_final_jrf_qa_508c pdf
#  pdf ofccp_eeo_supplement_final_jrf_qa_508c
#  product
#  experience
#  reasonable
#  gov employers
#  eeoc gov
#  www1
#  www1 eeoc
#  compliance
#  www
#  eeoc
#  software
#  http www
#  status
#  eeo
#  http www1
#  employers upload
#
#
# Cluster 21:
#
#  database
#  sql
#  oracle
#  server
#  experience
#  databases
#  sql server
#  data
#  administrator
#  database administrator
#  dba
#  administration
#  recovery
#  performance
#  tuning
#  support
#  security
#  backup
#  systems
#  database administration
#  procedures
#  system
#  monitoring
#  management
#  required
#  maintenance
#  production
#  years
#  backup recovery
#  knowledge
#  replication
#  development
#  application
#  oracle database
#  design
#  work
#  performance tuning
#  skills
#  maintain
#  environment
#
#
# Cluster 22:
#
#  kpmg
#  godaddy
#  schwab
#  cgi
#  status
#  snap
#  data
#  magazine
#  gender
#  experience
#  applicants
#  kpmg llp
#  llp
#  work
#  military
#  will
#  origin ancestry
#  ancestry
#  employee
#  genetic information
#  clients
#  snap inc
#  employment
#  genetic
#  federal
#  pregnancy
#  creed
#  expression
#  information
#  development
#  godaddy com
#  people
#  ability
#  team
#  marital status
#  disability
#  marital
#  pregnancy childbirth
#  creed religion
#  childbirth
#
#
# Cluster 23:
#
#  sales
#  technical
#  customer
#  sales engineer
#  customers
#  pre sales
#  product
#  experience
#  solutions
#  pre
#  business
#  solution
#  sales team
#  support
#  engineer
#  technical sales
#  skills
#  team
#  ability
#  account
#  will
#  demonstrations
#  work
#  management
#  products
#  presentations
#  sales engineering
#  knowledge
#  engineering
#  requirements
#  security
#  technology
#  services
#  prospects
#  enterprise
#  network
#  selling
#  sales process
#  provide
#  client
#
#
# Cluster 24:
#
#  perform essential
#  essential
#  essential functions
#  perform
#  ability
#  functions
#  may
#  employee
#  required
#  job
#  made enable
#  disabilities perform
#  enable individuals
#  may made
#  work
#  duties
#  accommodations may
#  representative
#  equipment
#  must
#  reasonable accommodations
#  made
#  accommodations
#  physical demands
#  reasonable
#  individuals disabilities
#  xylem
#  disabilities
#  demands
#  described representative
#  physical
#  functions job
#  described
#  experience
#  skills
#  individuals
#  repair
#  enable
#  job reasonable
#  assigned
#
#
# Cluster 25:
#
#  leidos
#  vital missions
#  support vital
#  employees support
#  missions government
#  commercial customers
#  government commercial
#  missions
#  vital
#  government
#  commercial
#  civil health
#  experience
#  software
#  leidos reported
#  combination leidos
#  ended january
#  martin information
#  gs information
#  completed combination
#  virginia leidos
#  giving effect
#  leidos lockheed
#  2016 giving
#  leidos global
#  effect recently
#  leidos com
#  business gs
#  company 33
#  billion fiscal
#  year ended
#  customers qualified
#  january 2016
#  health markets
#  reported pro
#  company diverse
#  recently completed
#  33 000
#  security civil
#  customers headquartered
#
#
# Cluster 26:
#
#  ebay
#  cookies
#  ebay inc
#  view
#  commerce
#  ebay company
#  shape millions
#  courage imagination
#  imagination can
#  creating ambitious
#  passion courage
#  join ebay
#  ambitious inclusive
#  workplace join
#  joining purpose
#  share around
#  sell connect
#  commerce want
#  driven community
#  inspires passion
#  global commerce
#  company inspires
#  buy sell
#  want shape
#  proud part
#  future global
#  community dedicated
#  people buy
#  team shaping
#  can proud
#  can part
#  connect share
#  looking company
#  dedicated creating
#  inclusive workplace
#  purpose driven
#  interested joining
#  imagination
#  world re
#  courage
#
#
# Cluster 27:
#
#  lockheed martin
#  lockheed
#  martin
#  software
#  martin re
#  martin employees
#  engineering better
#  better tomorrow
#  works partners
#  us lockheed
#  company lockheed
#  world bring
#  proven performance
#  martin equal
#  tomorrow lockheed
#  bring proven
#  customers toughest
#  partners around
#  performance customers
#  employees based
#  challenges lockheed
#  innovation company
#  status job
#  re engineering
#  many
#  technology innovation
#  age protected
#  leading technology
#  engineering
#  toughest challenges
#  internationally business
#  locations many
#  territories join
#  states throughout
#  martin vast
#  nations territories
#  many nations
#  throughout internationally
#  based many
#  many states
#
#
# Cluster 28:
#
#  google
#  technical
#  google cloud
#  experience
#  cloud
#  engineers
#  qualifications
#  users
#  project
#  engineering
#  equivalent practical
#  product
#  projects
#  qualifications minimum
#  practical experience
#  google engineers
#  scale
#  youtube
#  products
#  customers
#  billions users
#  minimum qualifications
#  data
#  practical
#  teams
#  google 30
#  software
#  hardware
#  team
#  infrastructure
#  qualifications ba
#  large
#  keep
#  preferred qualifications
#  work
#  will
#  search
#  bs degree
#  program
#  technology
#
#
# Cluster 29:
#
#  data
#  experience
#  big data
#  big
#  analytics
#  hadoop
#  data engineer
#  spark
#  business
#  etl
#  will
#  sql
#  technologies
#  team
#  work
#  pipelines
#  systems
#  years
#  solutions
#  data quality
#  design
#  tools
#  processing
#  engineer
#  working
#  data warehouse
#  warehouse
#  platform
#  development
#  skills
#  python
#  large
#  build
#  data pipelines
#  engineering
#  using
#  quality
#  aws
#  analysis
#  new

# %% [markdown]
# ### Topic modeling using Gensim
#
# Note that there's a memory-friendly way to do this by streaming docs.
#
# https://github.com/RaRe-Technologies/gensim/blob/develop/docs/notebooks/Corpora_and_Vector_Spaces.ipynb
#
# This _should_ work in memory, but if not then we have a streaming method to fall back on.

# %%
# Save the corpus in its current state before making modifications
original_texts = texts

# %%
# remove words that appear only once
texts = [[word for word in document.lower().split() if word not in stop_words]
         for document in parsed_dataset]

from collections import defaultdict
frequency = defaultdict(int)
for text in texts:
    for token in text:
        frequency[token] += 1

texts = [[token for token in text if frequency[token] > 1] for text in texts]

# %%
# Build and store a dictionary
dictionary = gensim.corpora.Dictionary(texts)
dictionary.save('/tmp/jobs.dict')  # store the dictionary, for future reference

# %%
new_doc = "Human computer interaction"
new_vec = dictionary.doc2bow(new_doc.lower().split())
print(new_vec)  # All three words appear in the dictionary
# Out:
# [(29, 1), (777, 1), (1014, 1)]

# %%
corpus = [dictionary.doc2bow(text) for text in texts]
# store to disk, for later use
gensim.corpora.MmCorpus.serialize('/tmp/jobs.mm', corpus)

# %%
if (os.path.exists("/tmp/jobs.dict")):
    dictionary = gensim.corpora.Dictionary.load('/tmp/jobs.dict')
    corpus = gensim.corpora.MmCorpus('/tmp/jobs.mm')
    print("Used saved dictionary and corpus")
else:
    print("No dictionary or corpus available at that path")
# Out:
# Used saved dictionary and corpus

# %%
# Sanity check the dictionary
print(dictionary[1])
print(dictionary[1044])
print(dictionary[2500])
# Out:
# .net
# seeker
# humanity

# %%
# %%time
# Transformation using tf_idf
tfidf = gensim.models.TfidfModel(corpus)
corpus_tfidf = tfidf[corpus]
# Out:
# CPU times: user 14.6 s, sys: 70.4 ms, total: 14.6 s
# Wall time: 14.7 s

# %%
# %%time
# construct a model using Latent Semantic Analysis
lsi = gensim.models.LsiModel(corpus_tfidf, id2word=dictionary, num_topics=500)
# Out:
# CPU times: user 1min 56s, sys: 6.74 s, total: 2min 2s
# Wall time: 1min 12s

# %%
# %%time
# construct another model using Hierarchical Dirichlet Processing
hdp = gensim.models.HdpModel(corpus, id2word=dictionary)
# Out:
# CPU times: user 6min 41s, sys: 19.6 s, total: 7min
# Wall time: 6min 36s

# %%
with open('sample_resume.txt', 'r') as infile:
    resume = infile.read()
doc = parse_input_docs(resume)
vec_bow = dictionary.doc2bow(doc.lower().split())
vec_lsi = lsi[vec_bow] # convert the query to LSI space

# %%
# transform corpus to LSI space and index it
index = gensim.similarities.MatrixSimilarity(lsi[corpus])

# %%
index.save('/tmp/jobs.index')

# %%
sims = index[vec_lsi]
sims_sorted = sorted(enumerate(sims), key=lambda item: -item[1])
for item in sims_sorted[:5]:
    print(all_job_titles[item[0]]+'\nID: '+all_job_ids[item[0]],"\n\tIndex:",item[0],"\n\tSimilarity:",item[1])
# Out:
# Java Software Engineer ( Microservices)
# ID: 8872b775eb7cab9f
# 	Index: 38415
# 	Similarity: 0.78755414
# Web DevOps Engineer
# ID: f6c96bb60e22c12b
# 	Index: 4892
# 	Similarity: 0.78742665
# Software Developer
# ID: da95cfcf76084c53
# 	Index: 16792
# 	Similarity: 0.78210187
# Software Engineer
# ID: c4872866cc29f339
# 	Index: 35603
# 	Similarity: 0.7818614
# Database Administrator
# ID: a60da84dcba79745
# 	Index: 28238
# 	Similarity: 0.7818416

# %% [markdown]
# #### Reflection
# Hmmm, those results don't seem super helpful. Moving onto SpACy.

# %% [markdown]
# ## SpaCy
# From [this example on Github](https://github.com/skipgram/modern-nlp-in-python/blob/master/executable/Modern_NLP_in_Python.ipynb)
#
# Installation had some oddities; run the following:
# ```bash
# $ pip install -U spacy
# $ python -m spacy download en
# ```
#
# I tried first without preprocessed "skill phrase" text as the corpus. Then, I ran back through with the "skill phrase" text. Both types of models and text output docs are saved in this directory.

# %%
import spacy
import pandas as pd
import itertools as it
import en_core_web_sm

import spacy
nlp = spacy.load('en')

# %%
parsed_jd = nlp(job_str)
print(parsed_jd)
# Out:
# Data Scientist/Machine Learning Engineer, Adaptive Authentication
# Position Description:
#
# This is an opportunity to join our fast-growing Adaptive Authentication team to develop cutting-edge risk-based adaptive authentication policies. We are looking for a Data Scientist/Machine Learning Engineer to build large-scale distributed systems while using machine learning to solve business problems. The ideal candidate has experience building models from complex systems, developing enterprise-grade software in an object-oriented language, and experience or knowledge in security, authentication or identity.
#
# Our elite team is fast, innovative and flexible; with a weekly release cycle and individual ownership we expect great things from our engineering and reward them with stimulating new projects and emerging technologies.
#
#
# Job Duties and Responsibilities:
#
# Build and own models that identify risk associated with anomalous activity in the cloud for authentication
# Build Machine Learning pipelines for training and deploying models at scale
# Analyze activity data in the cloud for new behavioral patterns
# Partner with product leaders to define requirements for building models
# Work closely with engineering lead and management to scope and plan engineering efforts
# Test-driven development, design and code reviews
#
# Required Skills:
#
# 2+ years of Data Science/Machine Learning experience
# Skilled in using machine learning algorithms for classification and regression
# 5+ years of software development experience in an object-oriented language building highly-reliable, mission-critical software
# Excellent grasp of software engineering principles
# Experience with multi-factor authentication, security, or identity is a plus
#
# Education:
#
# B.S, M.S, or Ph.D. in computer science, data science, machine learning, information retrieval, math or equivalent work experience
#
# Okta is an Equal Opportunity Employer

# %%
from gensim.models import Phrases
from gensim.models.word2vec import LineSentence

# %% [markdown]
# 1. Segment texts (JDs) into sentences & normalize text
# 2. First-order phrase modeling $\rightarrow$ apply first-order phrase
# 3. model to transform sentences
# 4. Second-order phrase modeling $\rightarrow$ apply second-order
# 5. phrase model to transform sentences
# 6. Apply text normalization and second-order phrase model to text of complete reviews

# %%
def punct_space(token):
    """
    helper function to eliminate tokens
    that are pure punctuation or whitespace
    """
    
    return token.is_punct or token.is_space

def line_review(filename):
    """
    SRG: modified for a list
    generator function to read in reviews from the file
    and un-escape the original line breaks in the text
    """
    
    for review in filename:
        yield review.replace('\\n', '\n')
            
def lemmatized_sentence_corpus(filename):
    """
    generator function to use spaCy to parse reviews,
    lemmatize the text, and yield sentences
    """
    
    for parsed_review in nlp.pipe(line_review(filename),
                                  batch_size=10000, n_threads=4):
        
        for sent in parsed_review.sents:
            yield u' '.join([token.lemma_ for token in sent
                             if not punct_space(token)])

# %%
# %%time

import codecs
# This is time consuming; make the if statement True to run
if 0 == 0:
    with codecs.open('spacy_jds_concat_parsed.txt', 'w', encoding='utf_8') as f:
        for sentence in original_texts:
            f.write(sentence + '\n')
# Out:
# CPU times: user 287 ms, sys: 105 ms, total: 393 ms
# Wall time: 397 ms

# %%
unigram_sentences = LineSentence('spacy_jds_concat_parsed.txt')

# %%
# print some examples
# for unigram_sentence in it.islice(unigram_sentences, 230, 240):
#     print(u' '.join(unigram_sentence))
#     print(u'')
# Out:
# Job Description Visa's Digital and Mobile Product Development (DMPD) team is building a new generation of products to facilitate commerce in everyone's digital and mobile lives. Our focus is to build intuitive features that expose profound new value for our customers, merchants and developers. As a Senior DevOps Engineer for Platform Engineering and Operations Support, you will join a team focused on making DMPD applications always available. The team is responsible for continuous integration, extending scalability, availability, and resiliency of DMPD products like Visa Checkout, Visa Direct, Visa Token Services, and Visa Digital Commerce Apps. You will help build and roll-out a platform for containerizing applications with monitoring, logging, and features like auto-scaling and auto-healing. Responsibilities: Develop continuous integration and management solutions for containers Build, enhance and scale critical pipeline, application, and infrastructure technologies in DMPD Build solutions for automated management, deployment and monitoring of application components used by critical business applications and engineers in DMPD Build and monitor a highly performance oriented infrastructure Responsible for provisioning and supporting engineering application/environment; focusing on faster provisioning, reliability and consistency. Drive productivity through engineering fundamentals, building core frameworks and implement best practices Qualifications 5+ years track record of relevant work experience and a B.S. or an M.S. in Computer Science or related technical discipline is required Should have hands on and good understanding on DevOps tools and automation framework Knowledge on Source Control Tools such as GIT, Bitbucket Continuous Integration (CI) tools such as Jenkins Must be proficient in one or more scripting languages: Unix Shell, Perl, Python Working experience in cloud computing, PaaS, IaaS, and related areas are highly desirable Working knowledge of Chef & Docker highly preferred Knowledge and experience with Linux OS Should have working experience with monitoring tools like Zabbix, OPNET, and/or SPLUNK, or any other monitoring tools/processes. Experience working in Agile environments Strong Automation and problem solving skills and ability to follow through to completion Additional Information All your information will be kept confidential according to EEO guidelines. Visa - 30 days ago
#
# Description: Leidos is seeking a Software Developer possessing the ability to design, develop, and implement end-to-end solutions. The successful candidate will assist in the design, development, implementation and maintenance of systems, software, custom applications, and data integration solutions with a focus on both desktop and web based geospatial applications. The candidate will interact with GIS production staff and other developers from junior to senior level. Demonstrated experience working as part of an integrated development team for the creation of complex applications. An understanding of the ESRI ArcGIS suite of products is a plus. Qualifications: Skills/Requirements: US Citizenship required per contract. 1+ years professional experience, or equivalent educational experience, in design, development, and implementation. Experience Microsoft .NET (desktop and web), Python, Web Services, HTML, CSS, and JavaScript Experience with databases such as SQL, MySQL and PostGreSQL. Understanding of application architecture best-practices. Knowledge of GIS technology. Experience with open source mapping application technologies such as, but not limited to, OpenLayers, Leaflet, Mapbox and GeoServer, a plus. Familiarity with source control practices and software such as GitHub and SourceTree. Must have the analytical and interpersonal skills to elicit and document business, functional, and technical requirements. Ability to troubleshoot a wide variety of technical issues. Ability to work as a team member in a fast-paced, deadline-oriented environment. Ability to understand and interpret business applications and is responsible for developing applications and products to fulfill those requirements. Education/Training: A Bachelor's degree from an accredited college or university with major course work in GIS, Computer Science; or other applicable major. In lieu of a four year degree, applicants with considerable progressive experience with GIS application development and GIS systems may be considered. Leidos Overview: Leidos is a global science and technology solutions leader working to solve the world’s toughest challenges in the defense, intelligence, homeland security, civil, and health markets. The company’s 33,000 employees support vital missions for government and commercial customers. Headquartered in Reston, Virginia, Leidos reported pro forma annual revenues of approximately $10 billion for the fiscal year ended January 1, 2016 after giving effect to the recently completed combination of Leidos with Lockheed Martin's Information Systems & Global Solutions business (IS&GS;). For more information, visit www.Leidos.com. The company’s diverse employees support vital missions for government and commercial customers. Qualified women, minorities, individuals with disabilities and protected veterans are encouraged to apply. Leidos will consider qualified applicants with criminal histories for employment in accordance with relevant Laws. Leidos is an Equal Opportunity Employer. Leidos - 30+ days ago
#
# Job Location: Columbia, Maryland Job Type : Full-time Experience : 7+ to 10 years Minimum experience: Bachelor's Degree Job Category: Information Technology - Business Intelligence Responsibilities: Provide system installation support including; packaging breakout and installation of equipment; create installation drawings/instructions, cable management (to include fiber, coaxial, and twisted pair); initial OS and application software installation; generate as-built documents; initial system configuration and equipment checkout for proper operation including system implementation and troubleshooting support as it relates to the Keysight GSM, UMTS, and LTE network monitoring system elements. Provide ongoing support of installed base of systems; remote and on-site troubleshooting, software and hardware updates; including 24/7 remote telephone support as needed Provide solution design recommendations. Ensure software packages and as-built documents are current. Duties also include: network planning, lab testing, lab support and troubleshooting and system administration support as related to Keysight systems deployed in the field or in customer lab facilities. Planning and coordinating large and small scale network projects within a multi-vendor infrastructure environment in voice and data telecommunication networks. Provide multi-level on-site customer training as it pertains to survey, planning, and installing system functionality and system operation. Provide labor reporting, inventory management, indirectly manage other system engineers assigned to the program As availability permits, support sales personnel in pre-sales activities for new business opportunities. Job Qualifications Must have active security clearance 8+ years relevant experience required Experience with hands-on rack and stack, installation, commissioning, and maintenance of telco grade servers and systems Experience creating install guides and as-built documentation Linux system and network administration experience Experience with firewall and vpn configuration Experience with scripting languages and programming a plus; python, perl, shell, vi Strong knowledge of networking protocols such as TCP/IP, NAT, routing, and switching Working knowledge of GSM, UMTS, and LTE mobile network architectures and protocols Networking and security certifications a plus Strong customer service and interpersonal skills; excellent written and verbal communication skills Program management experience a plus Bachelor's degree or equivalent education and experience Active or recent US Security Clearance Position will be located in Columbia, Maryland. Global Pharmatek - 30+ days ago
#
# Job Description: " Object oriented python hands-on programming experience of at least 5 years is mandatory. " Hands-on experience of minimum 3 years on Linux is mandatory " Knowledge of Server / Storage / Network platforms a big plus " Knowledge of Autotest framework is a big plus Global Pharmatek - 24 days ago
#
# About Make.TV Make.TV is the leading provider of cloud-based, live video acquisition and management solutions through its Live Video Cloud (“LVC”) platform. Think of it as a video router and switcher in the cloud. The company was originally founded in Germany (where most of the development team remains) and has moved its headquarter to Seattle in 2016. The company provides unmatched solutions for top media, entertainment and technology companies worldwide, including ESL, MTV/Viacom, MLB/BAMTech, FOX Sports Brasil, and the Swiss Broadcasting Corp (SRF). Make.TV’s award-winning Live Video Cloud helps content programmers and service providers in the fields of news, sports, eSports and entertainment bring live and on-demand video to any screen, from any source, mobile video or traditional cameras – all at once. Make.TV's investors include Microsoft Ventures, Voyager Capital and Vulcan Capital. We are working agile in flat hierarchies, maintaining a lot of freedom and ownership in regards of self-organization, selection of tools and other responsibilities. Due to our distributed organization with offices in Seattle, USA and Cologne, Germany and a satellite office in Los Angeles, we can offer to work from remote locations as well. In general, we foremost care about what is achieved and not from which place - although we feel you should visit the beautiful places we chose! We are mature enough to structure processes well and to avoid quite some mistakes, but still "startup enough" to move quick and adopt if things can be improved. More information is available at www.make.tv [http://www.make.tv/] Responsibilities: Implementation of LVC backend services and Improve the availability, latency and scalability of Make.TV’s services Solve problems relating to mission-critical services and build automation to prevent problem recurrence Influence the designs and architectures for large-scale distributed systems Required Qualifications: Working proficiency and communication skills in verbal and written English Proficient knowledge of Linux server operating systems BS degree in Computer Science or related technical field, or equivalent practical experience Proficient Go programming skills Experience with one or more of: AWS, Google Cloud, Microsoft Azure, C, C++, Java, Python, gRPC, Docker, Kubernetes Experience with large-scale distributed systems and resilience patterns Understanding of processes, threads, concurrency issues, locks and Linux performance monitoring (strace et. al) Strong problem-solving skills; understanding of algorithms and complexity analysis Expertise in designing and implementing microservice architectures What the Job offers: Colleagues with outstanding, long-term experience and an environment in which learning and development are highly important technically challenging tasks most modern technologies and procedures freedom in the improvement of own working methods Terms: Job-Type: Full-Time Employment: Permanent Place of work: Seattle/USA You are highly motivated and curious about this Job? Please send applications (with CV, job references etc.) with salary expectations and earliest start date. [https://www.make.tv/topic.php?tt/page_id=251] We look forward to hearing from you soon! Make.TV - 21 days ago
#
# Google's projects, like our users, span the globe and require managers to keep the big picture in focus. As a PLM Operations Program Manager at Google, you lead complex, multi-disciplinary projects. You plan requirements with internal customers and usher projects through the entire project lifecycle. This includes managing project schedules, identifying risks and clearly communicating goals to project stakeholders. Your projects often span offices, time zones and hemispheres, and it's your job to keep all the players coordinated on the project's progress and deadlines. The PLM team is a broad reaching partner, trusted to provide and build a culture around quality product data management from concept to end-of-life. We employ consistent, end-user focused processes and maintain a secure single source of truth in order to enable efficiency, scalability, and product excellence. As a Product Lifecycle Management (PLM) Program Manager, you will be the primary force driving effective management of product data throughout the lifecycle of our consumer hardware products. You will work with the Engineering team, Product team, and external partners to enable the development, launch, and sustainment of the product. You are well versed in PLM systems, product data management, and product development business processes. Google's mission is to organize the world's information and make it universally accessible and useful. Only one thing consistently stands in the way between our users and the world's information - hardware. Our Hardware team researches, designs, and develops new technologies and hardware to make our user's interaction with computing faster, more powerful, and seamless. Whether finding new ways to capture and sense the world around us, advancing form factors, or improving interaction methods, our Hardware team is making people's lives better through technology. Responsibilities Engage with engineering and product teams proactively to plan PLM activities (Parts, BOMs, SKUs, Engineering Changes, etc.) Prioritize PLM activities across multiple projects. Manage and execute the creation and audit the release of product data in Agile PLM. Ensure the Product BOM is complete and accurate throughout the product lifecycle. Manage project risks and resolve issues and escalations. Take ownership of PLM processes and policies and drive adoption with stakeholders. Perform audit and reconciliation of external partner product data. Qualifications Minimum qualifications: BA/BS degree or equivalent practical experience. 3 years of industry experience in one or more of the following fields: Product Data Management, New Product Introduction (NPI), manufacturing operations, development or operations engineering. 3 years of Engineering Change Management experience supporting multiple projects. Computer applications experience. Preferred qualifications: 2 years of consumer electronics experience. Agile PLM experience. Experience working on hardware products defining Bill of Materials structures and product documentation. Experience across all phases of product development from prototype to mass production to end-of-life. Highly organized, and excellent attention to detail; quick learner with creative problem-solving and analytical skills. An excellent communicator of project requirements and schedules with the ability to influence peers and managers in cross-functional and global teams. Google - 30+ days ago
#
# dv01 is a data management, reporting, and analytics platform that brings transparency and insight to lending markets- making them more efficient for institutional investors and safer for the world. In a nutshell, we’re doing our part to prevent a repeat of 2008. As the technological hub between lenders and capital markets, dv01 provides all parties with unprecedented data transparency, insight, and analytics. To date, dv01 has offered institutional investors insight into $15+ billion of securitizations and more than $64 billion of consumer, small business, real estate, auto, and student loans from the largest online lenders, including LendingClub, Prosper, and SoFi. YOU WILL: --------- Build the next generation of financial models: You’ll build data driven models covering trillions of dollars of consumer and business debt. To do so, you’ll have a massive quantity and variety of data at your disposal, some of which is only available in aggregate through dv01. Be intellectually stimulated: You will be exposed to new ideas across data science, finance, and economics. You will also be exposed to the latest research in relevant fields, and be guided by both coworkers and external academic advisors. Be an integral part of a top priority project: You’ll work closely with industry experts within and outside of dv01 to understand the data in the context of the market. You will work closely with the product team to understand which models best solve the customer needs, and with the engineering teams to realize that vision. Be customer facing: You’ll regularly publish private and public white papers and decks on dv01’s Intelligence effort. You will communicate directly with our customers, which include top hedge funds and banks, to integrate their knowledge into our models. YOU ARE: -------- Data driven: You believe in the importance of quality, timely, and comprehensive data in constructing models. You are able to quickly structure large and messy datasets to experiment with a variety of models, regularly perform data analysis on datasets larger than 1GB, and have trained models on 100’s of GBs of data. Practical problem solver: You have a strong statistical background and understand the tradeoffs and pitfalls of various data science techniques. You have an extensive toolset to determine mathematical and practical soundness of your models and avoid overfitting. Experienced with model productization: You are experienced with all stages of the data science lifecycle and understand the additional considerations and effort needed to make a model useful for customers, including customer systems integrations, deployment, automation, and maintenance. Enthusiastic about expanding your financial knowledge: You’re excited to learn more about the intricacies of the financial system. You are adept at learning on the job and unafraid to dive in to technical finance books. QUALIFICATIONS: --------------- 3+ years of experience or PhD/Masters in a field such as math, physics, or computer science Highly experienced with ad-hoc data analysis tools such as R, Python, Stata, SAS, or SQL Fundamental/broad understanding of data mining and predictive analytics techniques dv01 is an equal opportunity employer and all qualified applicants and employees will receive consideration for employment opportunities without regard to race, color, religion, creed, sex, sexual orientation, gender identity or expression, age, national origin or ancestry, citizenship, veteran status, membership in the uniformed services, disability, genetic information or any other basis protected by applicable law. dv01 - 30+ days ago
#
# Phase Change Software, headquartered at the base of the Rockies in beautiful Golden, Colorado, is a small startup company with the big idea of transforming code into data that can be queried, analyzed, compared and combined. Our patent pending methods for software analysis will dramatically improve software development productivity. Our work is at the bleeding edge of what is mathematically provable, knowable and programmable. If you are passionate about Artificial Intelligence and building software that will have a lasting impact on the future, then we might be what you’ve been looking for. You are the creative energy behind Mia. She is our intelligent AI agent who can sniff out the most intricate details of those monolithic systems that were built before the turn of the century. One of your many talents is creating elegant knowledge-driven visualizations that make complex systems understandable and logical. You can help us bring Mia to life – and help us build a wonderfully useful “face” on our incredibly powerful engine. You’ll love Mia when you get to know her…… Here’s what needs to be accomplished: Taking highly disorganized, random and wildly abstract concepts as input and delivering refined, rational illustrations as output Prototyping morning, noon and night until you can translate the concepts into a universally understood representation – you won’t stop until you can pictorialize the vision! Navigating through abstract ideas with creative energy – negotiating between the pragmatic reality of code and creative defiance Applying a minimalist design to your prototypes – after all, our audience is pretty geeky Grokking computer science principals and translating them into visual concepts Stretching yourself intellectually – challenging conventional thinking with a positive and curious mind Pitching in wherever you can when another team gets buried And what it’ll take to get it done: Bachelor’s degree in Human Computer Interaction or Industrial Design or related visualization design experience with a solid grasp of user-centered design, user research and rapid prototyping At least 4 years of professional experience building complex designs in a technical or scholarlyocused organization – no cat gifs for you Extra points for experience with 3D animation, AI or building collaborative agents Advanced knowledge of HTML5, CSS3 and 3D rendering Unshakeable commitment to the invention process – discover, iterate, rinse, repeat A fascination for how the mind works and how AI can aide in the absorption of the unknown Demonstrated experience as a team lead or senior contributor on a small, highly-collaborative team Comfortable pushing the state of the art and experimenting with unproven ideas A belief that iteration and evolution is the cornerstone to sound invention Understanding the balance between ambition and practical constraints when thinking through design concepts Passionate about technology and cognitive thought – what is the visual future of AI? Our team enjoys: Competitive salary and impressive suite of benefits Comfortable office with views of the mountains and at least one family dog to pet An incredible brain trust to work with every day Goldstone Partners is helping this amazing team of inventors identify outstanding professionals who want to make their mark. Learn more https://goldstonepartners.com/find-a-job/. Principals only please. Sponsorships cannot be supported at this time. Job Type: Full-time 3 days ago
#
# Company Mission and Highlights: mPulse Mobile, the leader in mobile health engagement, drives improved health outcomes and business efficiencies by engaging individuals with tailored and meaningful dialogue. mPulse Mobile combines technology, analytics and industry expertise that helps healthcare organizations activate their consumers to adopt healthy behaviors. With 9 years, 60+ healthcare customers, and more than a hundred million messages sent annually, mPulse Mobile has the data, the experience and the technology to drive healthy behavior change. Our Core Values: Model Integrity and Collaboration Drive Innovation and Thought Leadership Support Decision Making at All Levels Create Value for Clients by Empowering Consumers Improve Customer Experience Through Simple Design Celebrate Success… Often Purpose of the Role: mPulse Mobile is looking for talented Full Stack Software Engineer that will fit into internal technology team. This role is primarily focused will be involved in a combination of new feature development, API enhancement, optimization, client integration support and product maintenance. In addition, this role will collaborate with our offshore development partner to continue to deliver and support a high quality intelligent mobile messaging product. Finally, based on seniority and experience, the role will include mentoring and training of junior engineering team members. The ideal candidate is a mid-level software engineer having worked with technologies used by mPulse, such as Python, Postgres, SQL and other web engineering technologies. He or she should also have a passion for making the consumer healthcare experience better using communication technology. Duties and Responsibilities: Analyze and provide detailed defect reports and feature requests Provide technical product support to customers as well as internal staff, through web interface, via email and phone when appropriate Document problem resolutions in our defect tracking system Provide guidance to non-technical team members researching technical issues Work with development, testing and documentation teams during product development cycle to ensure quality control Investigate, develop and present formal and informal training on ms4 and ms5 products and support issues Co-author training plans and support new product team members as well as key customers Experience troubleshooting mobile applications and operating system problems Skills, Abilities, and Experience: High level proficiency in Python language with at least 2+ years of professional experience in Python Good command over advanced Python concepts such as iterators, generators, list comprehensions SQL query writing and experience working with ORMs such as SQL Alchemy Hands-on experience in SQL (Postgres) Proficiency on the LINUX (CentOS) command line and in UNIX shell scripting Python and SQL profiling/tuning experience would be a nice to have Working knowledge of OOP and Relational DB Professional experience using RabbitMQ, Celery, Redis, and SQLAlchemy Healthcare industry experience is a big plus Preferred B.S or equivalent experience in technology related field such as Computer Science, Business Administration or Marketing Behavioral Competencies: Strong aptitude and passion for technology and technology related innovation Ability to think creatively and excellent problem solving skills Extreme patience, ability to listen, a sense of humor and a controlled tenacity for delivering results Willing to quickly learn new methodologies and systems Must have strong sense of urgency and experience working with internal and external member teams Can take charge and thrive in uncharted territory or ambiguous circumstances Strong analytical skill set to decipher client needs and recommend solutions The Perks: Enjoy Unlimited PTO and flexible work hours Full Vision, Dental and Healthcare - all individual premiums paid by mPulse! 401K Program with a 4% match Weekly team lunches to celebrate victories P ...
#
# Senior Software Engineer SevOne strives for excellence in application-aware network performance management. The strength of our software solutions, innovative architecture, and rapid growth have created the need for talented, driven individuals to join our team and take our company to the next level! What will you do? As a member of our Universal Collection development organization, you will be part of a scrum team responsible for solving complex technical problems related to distributed systems. This team deploys software advancements that focus on the high speed reliable data ingestion into our SevOneNMS product. You will find yourself immersed in a variety of complex distributed computing, networking and coding challenges. Best of all, you will get to own these issues and see your hard work pay off through resolution and happy customers. We need strong critical thinkers who are able to learn new technologies quickly; therefore our ideal candidate may possess just a few, some, or a combination of the desired technologies. Requirements 5+ years of professional working experience. Bachelor’s degree in Computer Science, Engineering, or equivalent is preferred. Self-motivated and highly ambitious Ability to balance multiple project deliverables Strong written and verbal communication Experience working in multinational / multicultural environment Excellent teamwork and people skills Critical thinking & problem solving skills Strong troubleshooting and debugging skills Experience working with Linux. Redhat/Centos or Gentoo is preferred Experience with modern cloud technologies, such as Docker. Experience with distributed systems Ability and experience developing software solutions using different programming languages including Java, Golang, Python, PHP, Perl/Bash and C++ Experience with TDD Bonuses Telecommunications and Networking domain experience Experience with source control systems such as Git and Maven Web Service, Framework & Development Experience RESTful API development Master's degree in Computer Science, Engineering or equivalent Core Responsibilities Develop high quality, reliable, maintainable, and predictable data ingestion mechanisms, built using repeatable processes to enable solutions in the Carrier and Enterprise space Attend and participate in all Scrum meetings for the team Documenting and testing of features Writing automated unit, functional and integration tests Code reviews Increasing distributed nature of the product Assisting, coaching and mentoring others, leading small teams Responding to, and managing change on projects; Ability to handle multiple tasks simultaneously Demonstrating expertise in the following areas: Networking, Troubleshooting/Debugging, Telecommunications SevOne perks Unlimited PTO (work it out with your team first!), company observes 10 Holidays a year Make a real difference - your code reaches millions of people through our Fortune 100 Customers Work in a fun, casual, team environment – flip flops + T-shirts = OK Nerf Guns, Ping Pong, Foosball, gaming rooms and a two story slide! Free Food: Catered payday lunches, unlimited snacks and drinks Competitive benefits that start on day one! Education Reimbursement, Employee Loyalty Program, Innovation Time-Outs, and much more. SevOne is an equal opportunity employer. At SevOne, we are committed to treating all applicants fairly based on their abilities, achievements, and experience without regard to race, national origin, sex, age, disability, veteran status, sexual orientation, gender identity, or any other classification protected by law. No agencies will be entertained for this role. SevOne - 30+ days ago

# %%
# %%time

bigram_model = Phrases(unigram_sentences)
bigram_model.save('spacy_bigram_model_all_PARSED')
# Out:
# CPU times: user 39.6 s, sys: 796 ms, total: 40.4 s
# Wall time: 40.5 s

# %%
# load the finished model from disk
bigram_model = Phrases.load('spacy_bigram_model_all_PARSED')

# %%
# %%time

with codecs.open('spacy_bigram_sentences_PARSED.txt', 'w', encoding='utf_8') as f:
    for unigram_sentence in unigram_sentences:
        bigram_sentence = u' '.join(bigram_model[unigram_sentence])
        f.write(bigram_sentence + '\n')
# Out:
# /usr/local/lib/python3.6/site-packages/gensim/models/phrases.py:486: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")
# CPU times: user 1min 7s, sys: 141 ms, total: 1min 8s
# Wall time: 1min 8s

# %%
bigram_sentences = LineSentence('spacy_bigram_sentences_PARSED.txt')

# %%
# print examples; certain bigrams are underlined
# for bigram_sentence in it.islice(bigram_sentences, 240, 250):
#     print(u' '.join(bigram_sentence))
#     print(u'')

# %%
# %%time
trigram_model = Phrases(bigram_sentences)
trigram_model.save('spacy_trigram_model_all_PARSED')
# Out:
# CPU times: user 38.2 s, sys: 832 ms, total: 39 s
# Wall time: 39.4 s

# %%
# load the finished model from disk
trigram_model = Phrases.load('spacy_trigram_model_all_PARSED')

# %%
# %%time

with codecs.open('spacy_trigram_sentences_PARSED.txt', 'w', encoding='utf_8') as f:
    for bigram_sentence in bigram_sentences:
        trigram_sentence = u' '.join(trigram_model[bigram_sentence])
        f.write(trigram_sentence + '\n')
# Out:
# /usr/local/lib/python3.6/site-packages/gensim/models/phrases.py:486: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")
# CPU times: user 1min 8s, sys: 406 ms, total: 1min 8s
# Wall time: 1min 9s

# %%
trigram_sentences = LineSentence('spacy_trigram_sentences_PARSED.txt')

# %%
# for trigram_sentence in it.islice(trigram_sentences, 240, 250):
#     print(u' '.join(trigram_sentence))
#     print(u'')

# %% [markdown]
# #### Final preprocessing

# %%
# %%time

with codecs.open('spacy_trigram_transformed_jds_all_PARSED.txt', 'w', encoding='utf_8') as f:
    for parsed_review in nlp.pipe(line_review(original_texts),
                                  batch_size=10000, n_threads=4):
        # lemmatize the text, removing punctuation and whitespace
        unigram_review = [token.lemma_ for token in parsed_review
                          if not punct_space(token)]

        # apply the first-order and second-order phrase models
        bigram_review = bigram_model[unigram_review]
        trigram_review = trigram_model[bigram_review]

        # remove any remaining stopwords
        trigram_review = [term for term in trigram_review
                          if term not in stopwords]

        # write the transformed review as a line in the new file
        trigram_review = u' '.join(trigram_review)
        f.write(trigram_review + '\n')
# Out:
# /usr/local/lib/python3.6/site-packages/gensim/models/phrases.py:486: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")
# CPU times: user 1h 40min 23s, sys: 1h 37min 49s, total: 3h 18min 13s
# Wall time: 2h 17min 38s

# %%
print(u'Original:' + u'\n')

for review in it.islice(line_review(original_texts), 11, 12):
    print(review)

print(u'----' + u'\n')
print(u'Transformed:' + u'\n')

with codecs.open('spacy_trigram_transformed_jds_all_PARSED.txt', encoding='utf_8') as f:
    for review in it.islice(f, 11, 12):
        print(review)
# Out:
# Original:
#
# Position Overview  Are you a full stack Software Engineer looking for an opportunity to work in a fast paced and fun environment? Then consider joining us here at Skillsoft in Rochester, NY. We are building SaaS platforms and client applications for our content delivery products with the goal of being the “best in the industry”. Our products allow 6000+ customers consume content from a variety of sources with a strong focus on video, from any device, with features that fit the needs of learner. We believe that our customers deserve the best learning experiences and we are delivering on those needs with the products you will be working on. You could be the one to help us achieve this goal!  We are looking for exceptional developers to join our team and willing to learn new technology in this rapidly evolving world. You will build front end customer facing product features using cutting edge technologies while implementing REST APIs and other back-end functionality as needed.  Position Responsibilities    Build reusable code and libraries for future use  Ensure the technical feasibility of UI/UX designs  Optimize user-facing features for maximum speed and scalability  Collaborate with other team members and stakeholders to build user-facing features  Build prototypes and turn them into real production-quality features  Implement backend functionality as needed, such as REST APIs  Knowledge and Skills    Minimum of 3+ years of experience in web development – primarily on the front end using JavaScript, HTML5, and/or CSS3  Experience with Java and REST  Strong skills in JavaScript and using an MVW framework (React, Angular, Meteor, etc)  Experience with React and Redux or any modern JS framework (Ember, Angular, etc)  Experience with automation tools such as Npm, Webpack, Grunt, Bower etc.  Experience with code versioning tools, preferably Git (Github, Gitlab, etc) and the feature branch workflow  Proficient building responsive cross browser UI’s and exposure to mobile development  Experience of either SASS or LESS pre-processor  Experience in UI Test frameworks (CasperJS, PhantomJS, Mocha, Jasmine, JEST, Selenium, etc.)  Experience working in an Agile/Scrum environment  Demonstrated ability to ship code in production  Passionate, curious and open to new ideas  Education and Certifications  BS in Computer Science Preferred  Submit Profile  SumTotal Systems  -  30+ days ago
# ----
#
# Transformed:
#
# position overview -PRON- full_stack_software_engineer look_for an_opportunity work fast_paced fun environment consider join -PRON- here_at skillsoft rochester ny -PRON- build saas platform client application -PRON- content_delivery product goal good industry -PRON- product allow 6000 + customer consume content a_variety source strong_focus_on video any_device feature fit need learner -PRON- believe_that -PRON- customer deserve good learning experience -PRON- deliver need product -PRON- will_be work -PRON- could_be one help -PRON- achieve goal -PRON- look_for exceptional developer join -PRON- team willing learn_new technology rapidly evolve world -PRON- build front_end customer face product feature use cut edge_technology implement rest api back_end functionality need position responsibilities build reusable_code library future use ensure technical_feasibility ui ux design optimize user face feature for_maximum_speed scalability collaborate team_member stakeholder build user face feature build prototype turn -PRON- real production quality feature implement backend functionality need such_as rest api knowledge skills minimum 3_+ year experience web development primarily front_end use javascript html5 and/or css3 experience java rest strong skill javascript use mvw framework react angular meteor etc experience react redux modern js framework ember angular etc experience automation_tool such_as npm webpack grunt bower etc experience code version tool preferably git github gitlab etc feature branch workflow proficient building responsive cross_browser ui ’s exposure mobile development experience either sass less pre processor experience ui test_framework casperjs phantomjs mocha jasmine jest selenium etc experience work an_agile_scrum environment demonstrate ability ship_code production passionate curious open new idea education certifications bs computer_science preferred submit profile sumtotal systems 30 + day_ago

# %%
from gensim.corpora import Dictionary, MmCorpus
from gensim.models.ldamulticore import LdaMulticore
from gensim.models import LsiModel

import pyLDAvis
import pyLDAvis.gensim
import warnings
import pickle
# Out:
# /usr/local/lib/python3.6/site-packages/_pytest/fixtures.py:847: DeprecationWarning: The `convert` argument is deprecated in favor of `converter`.  It will be removed after 2019/01.
#   params = attr.ib(convert=attr.converters.optional(tuple))
# /usr/local/lib/python3.6/site-packages/_pytest/fixtures.py:849: DeprecationWarning: The `convert` argument is deprecated in favor of `converter`.  It will be removed after 2019/01.
#   ids = attr.ib(default=None, convert=_ensure_immutable_ids)

# %%
# %%time

trigram_reviews = LineSentence('spacy_trigram_sentences_PARSED.txt')

# learn the dictionary by iterating over all of the reviews
trigram_dictionary = Dictionary(trigram_reviews)

# filter tokens that are very rare or too common from
# the dictionary (filter_extremes) and reassign integer ids (compactify)
trigram_dictionary.filter_extremes(no_below=10, no_above=0.4)
trigram_dictionary.compactify()

trigram_dictionary.save('spacy_trigram_dict_all.dict')
    
# load the finished dictionary from disk
trigram_dictionary = Dictionary.load('spacy_trigram_dict_all.dict')
# Out:
# CPU times: user 16.4 s, sys: 245 ms, total: 16.7 s
# Wall time: 17.1 s

# %%
def trigram_bow_generator(filepath):
    """
    generator function to read reviews from a file
    and yield a bag-of-words representation
    """    
    for review in LineSentence(filepath):
        yield trigram_dictionary.doc2bow(review)

# %%
# %%time

# generate bag-of-words representations for all JDs and save them as a matrix
MmCorpus.serialize('spacy_trigram_bow_corpus_all.mm',
                   trigram_bow_generator('spacy_trigram_sentences_PARSED.txt'))
    
# load the finished bag-of-words corpus from disk
trigram_bow_corpus = MmCorpus('spacy_trigram_bow_corpus_all.mm')
# Out:
# CPU times: user 19.3 s, sys: 147 ms, total: 19.4 s
# Wall time: 19.4 s

# %% [markdown]
# ### Modeling

# %%
# %%time

with warnings.catch_warnings():
    warnings.simplefilter('ignore')

    # workers => sets the parallelism, and should be
    # set to your number of physical cores minus one
    lsi = gensim.models.LsiModel(trigram_bow_corpus, 
                                 id2word=trigram_dictionary, 
                                 num_topics=500)
    
    lsi.save('spacy_lsi_model_all')
    
# load the finished LDA model from disk
lsi = LsiModel.load('spacy_lsi_model_all')
# Out:
# CPU times: user 3min 2s, sys: 11.3 s, total: 3min 13s
# Wall time: 1min 41s

# %%
def explore_topic(topic_number, topn=10):
    """
    accept a user-supplied topic number and
    print out a formatted list of the top terms
    """
        
#     print(u'{:20} {}'.format(u'term', u'frequency') + u'')

    for term, frequency in lsi.show_topic(topic_number, topn=10):
        print(u'{:20} {:.3f}'.format(term, round(frequency, 3)))

# %%
for i in range(600):
    print("\n\nTopic %s" % str(i+1))
    explore_topic(topic_number=i)
# Out:
# Topic 1
# data                 0.266
# product              0.257
# support              0.157
# solutions            0.146
# design               0.136
# The                  0.132
# Ability              0.132
# including            0.131
# products             0.130
# systems              0.117
#
#
# Topic 2
# data                 0.695
# product              -0.584
# products             -0.172
# sales                -0.129
# systems              0.081
# customer             -0.078
# database             0.076
# customers            -0.074
# marketing            -0.073
# market               -0.070
#
#
# Topic 3
# data                 -0.565
# product              -0.556
# design               0.130
# -                    0.126
# systems              0.125
# applications         0.107
# solutions            0.103
# you                  0.100
# application          0.098
# your                 0.098
#
#
# Topic 4
# -                    -0.353
# your                 -0.280
# support              0.250
# you                  -0.249
# Ability              0.181
# data                 -0.167
# have                 -0.164
# we                   -0.138
# system               0.132
# including            0.125
#
#
# Topic 5
# -                    -0.892
# your                 0.110
# design               0.110
# :                    -0.107
# you                  0.095
# have                 0.084
# sales                -0.083
# support              -0.079
# Ability              -0.072
# &                    -0.071
#
#
# Topic 6
# sales                -0.447
# design               0.408
# product              0.287
# testing              0.221
# customers            -0.196
# customer             -0.168
# test                 0.145
# -                    0.142
# support              -0.138
# using                0.122
#
#
# Topic 7
# design               -0.615
# testing              0.339
# solutions            -0.320
# test                 0.209
# sales                -0.166
# *                    0.137
# product              0.125
# quality              0.124
# tools                0.112
# all                  0.104
#
#
# Topic 8
# design               -0.345
# solutions            0.292
# systems              0.217
# your                 -0.198
# Ability              -0.196
# technology           0.162
# security             0.157
# infrastructure       0.147
# you                  -0.146
# :                    -0.145
#
#
# Topic 9
# ·                    0.919
# &                    0.159
# solutions            0.103
# support              -0.100
# design               -0.087
# using                0.081
# database             -0.075
# systems              -0.065
# testing              0.064
# Ability              0.064
#
#
# Topic 10
# &                    0.594
# :                    0.557
# ·                    -0.239
# *                    0.226
# support              -0.137
# /                    0.118
# database             -0.115
# your                 -0.107
# you                  -0.105
# systems              -0.100
#
#
# Topic 11
# :                    -0.630
# *                    0.407
# testing              0.260
# ·                    -0.214
# sales                0.200
# systems              -0.182
# test                 0.145
# database             -0.139
# Ability              0.139
# support              -0.137
#
#
# Topic 12
# *                    -0.802
# testing              0.219
# Ability              0.195
# support              -0.161
# database             -0.136
# design               -0.128
# systems              -0.128
# ·                    -0.116
# ability              0.112
# test                 0.102
#
#
# Topic 13
# &                    -0.609
# :                    0.467
# testing              0.252
# sales                0.227
# customers            0.157
# The                  -0.143
# test                 0.141
# products             0.137
# solutions            0.128
# Ability              0.119
#
#
# Topic 14
# sales                0.361
# &                    0.308
# *                    -0.289
# solutions            -0.218
# products             0.218
# teams                -0.212
# project              -0.175
# technology           -0.171
# ability              -0.160
# design               0.156
#
#
# Topic 15
# The                  -0.445
# your                 0.329
# solutions            0.299
# o                    0.265
# you                  0.261
# ability              -0.218
# systems              -0.197
# products             -0.178
# testing              0.176
# database             0.157
#
#
# Topic 16
# Ability              0.623
# o                    -0.365
# The                  -0.360
# testing              -0.208
# database             0.186
# solutions            -0.137
# test                 -0.136
# using                0.113
# design               -0.107
# your                 0.104
#
#
# Topic 17
# o                    0.827
# Ability              0.309
# support              -0.205
# &                    -0.120
# ability              0.099
# testing              -0.098
# design               -0.098
# solutions            -0.078
# test                 -0.063
# products             0.063
#
#
# Topic 18
# using                0.320
# teams                -0.266
# The                  0.258
# systems              -0.230
# solutions            0.214
# product              0.194
# –                    0.186
# applications         0.185
# products             -0.181
# engineering          -0.173
#
#
# Topic 19
# support              0.523
# systems              -0.342
# solutions            -0.285
# teams                0.210
# tools                0.180
# database             0.171
# requirements         -0.157
# engineering          -0.146
# design               0.145
# system               -0.145
#
#
# Topic 20
# •                    0.642
# support              -0.345
# database             0.330
# all                  0.193
# Ability              -0.165
# engineering          -0.164
# your                 -0.153
# including            0.133
# products             0.118
# you                  -0.112
#
#
# Topic 21
# •                    -0.655
# database             0.366
# support              -0.330
# security             0.163
# –                    0.156
# all                  0.134
# engineering          -0.132
# sales                0.125
# products             -0.111
# using                -0.108
#
#
# Topic 22
# –                    0.355
# including            -0.317
# •                    0.307
# using                -0.275
# products             -0.252
# Ability              0.241
# systems              0.214
# ability              0.167
# customers            0.162
# developing           -0.140
#
#
# Topic 23
# sales                -0.290
# products             0.286
# solutions            0.254
# –                    -0.254
# ability              -0.204
# The                  0.204
# systems              -0.197
# Ability              0.182
# marketing            -0.173
# their                0.170
#
#
# Topic 24
# products             -0.628
# –                    -0.493
# sales                0.192
# their                0.190
# ability              -0.174
# your                 -0.139
# product              0.134
# using                0.116
# solutions            -0.109
# support              -0.105
#
#
# Topic 25
# –                    0.346
# /                    0.307
# database             -0.285
# The                  -0.247
# customer             0.204
# sales                -0.200
# all                  0.198
# customers            0.193
# will                 -0.191
# your                 -0.165
#
#
# Topic 26
# systems              0.360
# security             -0.302
# application          -0.245
# including            0.204
# your                 -0.184
# /                    -0.184
# The                  -0.182
# marketing            0.169
# engineering          -0.166
# solutions            0.158
#
#
# Topic 27
# /                    0.639
# security             0.264
# using                -0.213
# –                    -0.212
# including            0.195
# application          -0.190
# applications         -0.183
# teams                -0.165
# ability              -0.157
# database             -0.144
#
#
# Topic 28
# customer             -0.331
# including            -0.287
# database             -0.284
# all                  0.282
# customers            -0.275
# sales                0.268
# engineering          -0.228
# application          0.170
# systems              0.168
# tools                0.141
#
#
# Topic 29
# security             -0.434
# /                    0.354
# including            -0.320
# technology           0.268
# engineering          0.259
# database             0.219
# tools                -0.180
# customer             -0.135
# project              0.131
# have                 0.130
#
#
# Topic 30
# technology           0.432
# engineering          0.279
# /                    -0.266
# solutions            -0.244
# including            0.240
# systems              -0.232
# –                    0.213
# security             0.185
# using                -0.184
# at                   0.163
#
#
# Topic 31
# engineering          0.444
# solutions            0.298
# application          -0.243
# quality              0.227
# systems              -0.214
# tools                0.210
# technology           -0.207
# applications         -0.198
# all                  0.173
# testing              -0.168
#
#
# Topic 32
# including            -0.415
# security             0.384
# at                   0.235
# teams                0.198
# management           -0.187
# The                  -0.182
# and/or               0.175
# services             -0.175
# quality              -0.174
# all                  -0.171
#
#
# Topic 33
# have                 0.473
# The                  -0.261
# at                   -0.243
# your                 -0.195
# customer             -0.189
# teams                -0.180
# database             -0.178
# their                0.176
# will                 0.173
# from                 -0.171
#
#
# Topic 34
# +                    -0.715
# ability              0.257
# their                0.243
# will                 -0.192
# all                  -0.184
# customer             -0.176
# application          0.165
# using                -0.162
# marketing            -0.100
# tools                0.099
#
#
# Topic 35
# ability              0.482
# –                    -0.356
# +                    0.257
# technology           0.252
# their                -0.215
# project              -0.185
# engineering          -0.164
# customer             0.156
# Ability              -0.144
# will                 -0.138
#
#
# Topic 36
# +                    -0.516
# their                -0.418
# all                  0.311
# including            -0.213
# will                 0.197
# technology           0.182
# have                 0.173
# customer             0.164
# security             0.135
# your                 -0.129
#
#
# Topic 37
# using                -0.395
# technology           -0.390
# application          0.340
# including            0.281
# applications         0.211
# their                -0.207
# solutions            0.196
# have                 0.185
# management           -0.172
# your                 -0.168
#
#
# Topic 38
# at                   -0.425
# project              -0.346
# their                0.262
# all                  0.262
# will                 0.255
# system               0.157
# marketing            0.156
#                     -0.155
# develop              0.154
# management           -0.150
#
#
# Topic 39
# quality              -0.322
# ability              0.265
# system               0.264
# project              0.247
# at                   -0.214
# all                  0.211
# services             -0.190
# and/or               -0.178
# –                    -0.169
# will                 -0.161
#
#
# Topic 40
# system               0.373
# tools                0.346
# all                  -0.317
# teams                -0.252
# systems              -0.206
# management           0.199
# build                0.178
# testing              -0.172
# engineering          -0.163
# technology           0.156
#
#
# Topic 41
# from                 -0.381
# using                0.368
# management           -0.219
# including            0.210
# your                 -0.207
# teams                0.207
# at                   0.197
# you                  0.175
# ability              0.174
# services             -0.161
#
#
# Topic 42
#                     0.502
# by                   0.270
# skills               -0.243
# system               0.214
# services             0.210
# project              -0.208
# tools                -0.207
# using                0.186
# projects             -0.153
# customers            -0.132
#
#
# Topic 43
# quality              -0.414
# from                 -0.407
# at                   0.331
# services             0.207
# security             -0.207
# all                  0.198
# required             0.151
#                     0.135
# their                0.131
# requirements         0.120
#
#
# Topic 44
#                     0.449
# system               -0.237
# marketing            -0.229
# will                 0.228
# from                 0.228
# management           -0.196
# tools                0.195
# at                   -0.193
# technology           0.192
# applications         -0.190
#
#
# Topic 45
#                     -0.458
# skills               -0.249
# services             0.246
# from                 0.224
# and/or               0.221
# quality              -0.215
# have                 0.184
# security             -0.150
# systems              -0.148
# company              -0.148
#
#
# Topic 46
# system               -0.396
# from                 -0.278
# teams                -0.231
# ,                    0.217
# engineering          0.208
# you                  0.203
# your                 -0.203
# marketing            0.201
# project              0.172
# applications         0.171
#
#
# Topic 47
# will                 -0.303
# management           0.294
# ,                    0.284
# you                  0.227
# teams                0.206
# services             -0.206
# from                 0.198
# at                   -0.188
# project              -0.180
# your                 -0.172
#
#
# Topic 48
# management           0.336
# ,                    -0.331
# services             -0.310
# have                 0.270
# you                  -0.233
# tools                0.211
# .                    -0.211
# will                 -0.165
# project              -0.163
# your                 0.149
#
#
# Topic 49
# and/or               -0.414
# from                 0.372
# will                 0.247
# at                   0.184
# system               -0.179
# management           0.174
# The                  -0.165
# application          0.159
# ability              0.158
# engineering          0.155
#
#
# Topic 50
# ,                    -0.391
# .                    -0.248
# customer             0.240
# customers            -0.220
# requirements         0.217
# at                   -0.203
# will                 -0.187
# company              0.185
# you                  0.170
# all                  -0.154
#
#
# Topic 51
# management           0.332
# have                 -0.313
# you                  0.269
# ,                    -0.205
# your                 -0.203
# by                   -0.178
# customers            0.171
# tools                -0.169
# marketing            -0.167
# company              -0.166
#
#
# Topic 52
# within               -0.343
# tools                -0.295
# developing           -0.283
# build                0.274
# applications         -0.248
# and/or               0.223
# application          0.209
# marketing            0.178
# develop              -0.176
# you                  -0.173
#
#
# Topic 53
# skills               0.383
# and/or               -0.315
# application          0.273
# their                -0.231
# at                   -0.211
# by                   0.206
# customers            0.179
# services             0.176
# We                   0.159
# applications         -0.156
#
#
# Topic 54
# you                  -0.305
# build                0.259
# by                   0.237
# marketing            -0.235
# will                 0.228
# quality              -0.205
# company              0.196
# their                -0.184
# requirements         0.182
#                     -0.167
#
#
# Topic 55
# within               0.352
# requirements         -0.310
# have                 -0.274
# company              0.261
# Knowledge            -0.234
# will                 0.213
# teams                -0.198
# system               0.187
# develop              -0.174
# developing           -0.164
#
#
# Topic 56
# by                   -0.321
# company              0.269
# developing           -0.262
# building             -0.252
# customer             -0.242
# Work                 0.221
# customers            0.218
# skills               -0.210
# services             0.191
# you                  -0.172
#
#
# Topic 57
# within               -0.541
# customer             0.284
# customers            -0.268
# build                -0.234
# requirements         -0.220
# teams                0.211
# required             -0.184
# will                 0.163
# applications         0.140
# research             0.122
#
#
# Topic 58
# Knowledge            0.574
# by                   0.267
# build                -0.228
# skills               -0.212
# customer             -0.185
# building             0.171
# customers            0.165
# plus                 0.163
# developing           -0.151
# will                 0.146
#
#
# Topic 59
# Knowledge            0.421
# within               0.269
# customers            -0.248
# required             -0.231
# by                   -0.221
# customer             0.210
# build                0.193
# and/or               -0.170
# knowledge            0.164
# tools                -0.135
#
#
# Topic 60
# develop              0.341
# through              -0.250
# by                   0.234
# requirements         -0.216
# and/or               -0.196
# Work                 0.188
# company              0.170
# customer             0.167
# plus                 -0.163
# tools                -0.153
#
#
# Topic 61
# company              0.252
# by                   -0.217
# across               0.207
# we                   -0.191
# building             0.190
# marketing            -0.178
# within               -0.166
# related              0.164
# Knowledge            -0.163
# and/or               -0.159
#
#
# Topic 62
# marketing            -0.396
# through              0.280
# develop              0.243
# applications         -0.208
# test                 0.202
# developing           0.189
# system               -0.174
# and/or               0.162
# teams                -0.159
# application          0.153
#
#
# Topic 63
# build                -0.331
# through              -0.285
# tools                0.242
# applications         -0.225
# and/or               0.224
# Work                 0.203
# related              -0.187
# required             -0.186
# application          0.167
# building             0.156
#
#
# Topic 64
# applications         0.330
# company              -0.316
# developing           -0.304
# application          -0.222
# Work                 0.216
# marketing            -0.175
# develop              0.174
# skills               0.171
# infrastructure       0.163
# build                -0.150
#
#
# Topic 65
# required             -0.346
# skills               0.308
# building             -0.262
# company              0.240
# plus                 -0.228
# environment          -0.203
# IT                   0.185
# Knowledge            0.152
# by                   0.150
# services             0.150
#
#
# Topic 66
# through              -0.347
# requirements         0.299
# infrastructure       0.240
# IT                   0.205
# Work                 -0.203
# test                 0.178
# build                -0.172
# We                   0.163
# performance          0.155
# we                   0.152
#
#
# Topic 67
# test                 0.372
# across               0.336
# developing           -0.326
# required             0.239
# testing              -0.226
# by                   -0.158
# requirements         -0.152
# clients              -0.145
# customers            -0.135
# applications         0.132
#
#
# Topic 68
# related              0.358
# through              -0.291
# across               0.256
# test                 -0.198
# applications         -0.190
# building             -0.183
# IT                   0.182
# skills               -0.176
# knowledge            -0.171
# company              -0.170
#
#
# Topic 69
# knowledge            0.242
# develop              -0.238
# research             0.216
# Knowledge            -0.215
# building             -0.209
# requirements         0.201
# through              0.194
# Work                 0.186
# required             -0.169
# company              -0.161
#
#
# Topic 70
# plus                 0.468
# You_will             0.290
# by                   0.270
# building             -0.256
# Work                 -0.244
# through              -0.236
# clients              0.157
# Develop              -0.155
# develop              0.145
# help                 0.142
#
#
# Topic 71
# related              0.392
# test                 0.388
# quality              -0.200
# testing              -0.200
# required             -0.192
# one                  -0.183
# client               0.162
# requirements         -0.159
# internal             0.155
# research             -0.149
#
#
# Topic 72
# related              -0.287
# develop              -0.242
# one                  -0.229
# through              -0.225
# performance          0.221
# developing           0.199
# plus                 0.182
# research             0.175
# ensure               0.174
# building             -0.172
#
#
# Topic 73
# Work                 0.255
# research             -0.251
# one                  0.245
# develop              -0.237
# plus                 -0.219
# requirements         -0.215
# through              -0.193
# building             -0.187
# related              -0.185
# across               0.156
#
#
# Topic 74
# related              0.284
# IT                   -0.277
# knowledge            -0.237
# plus                 0.195
# develop              -0.159
# requirements         0.158
# global               0.156
# applications         0.144
# test                 0.142
# projects             0.142
#
#
# Topic 75
# knowledge            0.376
# performance          0.253
# test                 -0.248
# research             -0.245
# building             -0.193
# we                   0.189
# environment          -0.174
# one                  -0.165
# IT                   -0.149
# testing              0.147
#
#
# Topic 76
# internal             -0.272
# across               -0.190
# infrastructure       -0.174
# t                    -0.150
# environment          0.149
# developing           -0.148
# performance          0.145
# analysis             0.135
# required             -0.134
# research             -0.129
#
#
# Topic 77
# across               -0.352
# plus                 0.349
# knowledge            0.279
# IT                   0.254
# provide              -0.177
# client               -0.172
# related              -0.165
# process              0.155
# services             0.148
# Knowledge            -0.140
#
#
# Topic 78
# environment          0.462
# process              -0.295
# such_as              -0.196
# You_have             0.192
# we                   -0.157
# help                 0.154
# Strong               -0.148
# platform             -0.148
# projects             0.135
# You                  0.126
#
#
# Topic 79
# t                    0.401
# ,                    -0.347
# s                    0.250
# d                    0.225
# g                    0.168
# environment          0.166
# A                    0.162
# e                    0.162
# r                    0.150
# m                    0.136
#
#
# Topic 80
# knowledge            0.282
# performance          -0.269
# projects             0.263
# provide              0.225
# You_will             -0.188
# across               0.185
# information          0.183
# required             -0.182
# build                0.176
# environment          0.176
#
#
# Topic 81
# IT                   0.428
# projects             -0.315
# process              -0.273
# project              0.184
# one                  -0.175
# internal             -0.149
# related              0.147
# developing           0.141
# processes            -0.132
# customers            0.126
#
#
# Topic 82
# You_will             0.329
# provide              0.305
# research             -0.300
# information          0.210
# You_have             -0.203
# through              0.197
# one                  0.171
# required             -0.163
# Work                 0.155
# You                  -0.144
#
#
# Topic 83
# projects             -0.423
# IT                   -0.297
# project              0.265
# knowledge            0.223
# AWS                  0.211
# help                 0.208
# network              -0.147
# platform             -0.139
# environment          0.135
# build                -0.131
#
#
# Topic 84
# as_well_as           -0.280
# one                  -0.237
# process              0.233
# ensure               -0.222
# use                  0.193
# research             -0.159
# internal             -0.155
# environment          0.152
# code                 -0.148
# You_will             0.133
#
#
# Topic 85
# AWS                  -0.280
# provide              0.260
# we                   -0.197
# code                 0.178
# Oracle               0.162
# You_have             0.161
# Work                 -0.159
# process              0.159
# As                   0.157
# analytics            -0.156
#
#
# Topic 86
# Work                 0.340
# environment          -0.299
# one                  -0.287
# You_will             0.252
# information          -0.239
# develop              -0.167
# Oracle               0.162
# research             0.161
# process              -0.150
# As                   0.149
#
#
# Topic 87
# platform             -0.404
# across               0.228
# ensure               -0.211
# knowledge            -0.205
# research             -0.193
# internal             -0.186
# plus                 0.179
# code                 0.179
# environment          -0.172
# use                  0.162
#
#
# Topic 88
# plus                 0.264
# You_have             0.255
# one                  0.254
# process              -0.202
# as_well_as           -0.201
# code                 -0.199
# help                 -0.188
# You                  0.156
# You_are              0.152
# or_more              0.150
#
#
# Topic 89
# platform             0.302
# such_as              -0.283
# analysis             0.223
# process              -0.190
# Strong               0.181
# building             -0.170
# Work                 -0.168
# across               -0.166
# You_will             -0.164
# information          0.158
#
#
# Topic 90
# internal             -0.288
# AWS                  0.270
# You_will             0.255
# be                   -0.253
# help                 0.176
# required             0.169
# environment          -0.168
# as_well_as           -0.166
# projects             0.154
# processes            0.143
#
#
# Topic 91
# performance          -0.345
# platform             0.327
# Strong               -0.289
# help                 0.215
# internal             0.182
# use                  0.168
# skills               0.161
# mobile               -0.135
# developing           0.131
# provide              0.128
#
#
# Topic 92
# information          -0.319
# such_as              0.225
# provide              0.196
# ensure               -0.175
# required.            0.172
# client               -0.171
# drive                0.168
# research             -0.164
# You_have             0.153
# technologies         -0.153
#
#
# Topic 93
# be                   0.295
# such_as              0.290
# Develop              0.269
# help                 -0.205
# internal             -0.190
# process              -0.165
# drive                0.138
# research             -0.136
# people               0.136
# network              -0.131
#
#
# Topic 94
# help                 0.376
# Strong               0.346
# such_as              0.264
# network              0.198
# AWS                  -0.196
# ensure               0.177
# skills               -0.173
# information          0.155
# Work                 -0.151
# as_well_as           -0.146
#
#
# Topic 95
# analytics            -0.332
# ensure               -0.249
# such_as              0.238
# be                   0.218
# process              0.192
# internal             0.190
# performance          0.186
# Work                 0.156
# infrastructure       -0.152
# Oracle               -0.138
#
#
# Topic 96
# provide              0.375
# be                   0.249
# ensure               0.236
# such_as              -0.224
# internal             -0.202
# Strong               0.192
# one                  0.176
# use                  -0.176
# help                 0.175
# research             0.159
#
#
# Topic 97
# analysis             -0.340
# complex              0.288
# platform             0.241
# help                 0.234
# we                   -0.208
# internal             -0.192
# technologies         -0.177
# code                 -0.154
# provide              -0.153
# You_will             -0.149
#
#
# Topic 98
# Strong               0.327
# use                  0.298
# across               0.209
# skills               -0.166
# You_will             0.158
# technologies         -0.152
# IT                   0.141
# internal             0.140
# be                   -0.140
# provide              -0.137
#
#
# Topic 99
# complex              -0.273
# help                 0.241
# such_as              0.233
# performance          0.229
# You_will             -0.190
# process              -0.168
# use                  0.167
# projects             0.164
# as_well_as           -0.158
# technologies         0.150
#
#
# Topic 100
# be                   0.278
# information          -0.258
# Develop              0.213
# ensure               -0.188
# AWS                  -0.172
# code                 -0.171
# maintain             0.171
# Work                 -0.162
# Our                  -0.162
# we                   0.160
#
#
# Topic 101
# AWS                  0.266
# Develop              0.264
# processes            -0.260
# network              0.236
# such_as              -0.232
# automation           -0.201
# required.            0.190
# help                 0.181
# projects             -0.147
# technologies         0.147
#
#
# Topic 102
# complex              -0.399
# we                   -0.241
# required.            -0.213
# Strong               0.201
# Our                  0.179
# such_as              -0.147
# code                 -0.144
# engineers            0.140
# help                 0.140
# infrastructure       0.127
#
#
# Topic 103
# ensure               -0.266
# internal             0.264
# network              -0.252
# analysis             -0.229
# complex              0.202
# as_well_as           0.196
# help                 0.176
# drive                0.167
# AWS                  -0.156
# reporting            -0.148
#
#
# Topic 104
# we                   0.369
# We                   -0.278
# information          0.260
# as_well_as           0.227
# projects             0.212
# ensure               -0.211
# Our                  -0.194
# processes            -0.193
# performance          0.191
# complex              -0.168
#
#
# Topic 105
# technologies         -0.412
# use                  -0.234
# as_well_as           -0.213
# ensure               0.193
# processes            -0.185
# people               -0.147
# As                   0.146
# into                 0.145
# such_as              0.145
# Strong               -0.135
#
#
# Topic 106
# technologies         -0.339
# analytics            -0.304
# be                   -0.297
# as_well_as           0.248
# use                  0.227
# required.            -0.196
# internal             -0.194
# drive                0.184
# help                 0.152
# analysis             0.124
#
#
# Topic 107
# as_well_as           0.332
# information          0.281
# provide              -0.240
# global               0.201
# be                   -0.185
# You_will             0.168
# into                 0.164
# DevOps               0.156
# required.            0.155
# We                   0.153
#
#
# Topic 108
# drive                -0.377
# required.            -0.373
# complex              0.352
# as_well_as           0.238
# code                 -0.209
# AWS                  0.156
# infrastructure       -0.146
# Strong               0.137
# As                   0.123
# You_will             -0.114
#
#
# Topic 109
# program              0.274
# analytics            0.232
# architecture         0.230
# into                 0.219
# code                 0.209
# ensure               -0.193
# technologies         -0.192
# Oracle               -0.180
# network              0.161
# implementation       0.143
#
#
# Topic 110
# this                 0.312
# processes            0.217
# into                 0.208
# mobile               -0.188
# create               0.168
# program              0.168
# infrastructure       -0.166
# implementation       -0.162
# process              -0.158
# analysis             -0.144
#
#
# Topic 111
# program              -0.266
# provide              0.229
# into                 0.221
# create               0.219
# automation           -0.190
# AWS                  0.171
# processes            0.170
# required.            0.165
# drive                -0.165
# ensure               -0.148
#
#
# Topic 112
# processes            -0.345
# create               0.270
# network              -0.253
# infrastructure       0.219
# engineers            -0.194
# analysis             0.192
# technologies         0.177
# complex              0.158
# information          -0.151
# analytics            -0.133
#
#
# Topic 113
# processes            -0.307
# automation           0.282
# enterprise           0.206
# Java                 0.185
# research             0.165
# infrastructure       -0.158
# use                  0.153
# analysis             -0.150
# as_well_as           -0.144
# process              0.144
#
#
# Topic 114
# automation           0.231
# make                 0.198
# use                  0.192
# program              -0.187
# engineers            0.177
# this                 0.176
# infrastructure       -0.170
# provide              0.164
# ensure               0.160
# DevOps               0.146
#
#
# Topic 115
# We                   0.305
# As                   -0.246
# use                  -0.243
# Our                  -0.217
# drive                -0.208
# You_will             0.179
# processes            -0.155
# existing             -0.154
# etc.                 0.150
# AWS                  -0.141
#
#
# Topic 116
# create               -0.345
# engineers            -0.342
# deliver              -0.240
# into                 0.203
# Our                  0.185
# make                 0.178
# existing             0.150
# program              -0.142
# drive                0.129
# processes            -0.120
#
#
# Topic 117
# Our                  -0.321
# network              0.256
# both                 -0.235
# code                 0.189
# mobile               0.183
# deliver              0.169
# maintain             -0.155
# create               -0.153
# architecture         -0.150
# infrastructure       -0.149
#
#
# Topic 118
# Familiarity_with     0.239
# Our                  -0.236
# maintain             0.232
# deliver              -0.206
# As                   0.195
# Develop              -0.192
# make                 0.181
# both                 0.177
# into                 -0.175
# We                   0.172
#
#
# Topic 119
# engineers            0.336
# into                 0.306
# Our                  -0.191
# We                   0.181
# As                   0.181
# training             0.168
# technologies         0.166
# network              -0.164
# service              0.159
# drive                0.151
#
#
# Topic 120
# technologies         0.264
# automation           -0.208
# both                 -0.204
# mobile               -0.203
# enterprise           -0.203
# issues               0.199
# reporting            0.193
# etc.                 0.162
# QA                   -0.160
# into                 -0.149
#
#
# Topic 121
# create               -0.364
# both                 0.247
# mobile               0.220
# strong               0.200
# engineers            0.191
# network              -0.177
# Java                 -0.170
# as_well_as           -0.154
# We                   -0.149
# "                    -0.133
#
#
# Topic 122
# both                 -0.333
# maintain             0.278
# Java                 -0.223
# experience.          0.213
# Develop              -0.191
# mobile               -0.170
# deliver              0.168
# market               -0.158
# this                 0.147
# architecture         0.141
#
#
# Topic 123
# this                 0.250
# "                    0.241
# implementation       0.236
# deliver              0.217
# into                 -0.188
# issues               -0.188
# Familiarity_with     -0.187
# infrastructure       0.176
# program              -0.159
# As                   0.131
#
#
# Topic 124
# Java                 0.253
# etc.                 -0.251
# "                    -0.211
# implementation       0.202
# DevOps               -0.183
# various              -0.171
# deliver              -0.170
# into                 0.169
# required.            0.165
# enterprise           0.164
#
#
# Topic 125
# deliver              -0.302
# into                 -0.234
# QA                   0.214
# implementation       0.200
# drive                0.199
# architecture         0.197
# create               0.181
# various              0.179
# DevOps               -0.150
# network              -0.144
#
#
# Topic 126
# deliver              -0.246
# various              -0.237
# such_as              0.214
# etc.                 -0.207
# Familiarity_with     -0.185
# into                 -0.180
# lead                 0.164
# maintain             0.162
# code                 0.158
# people               -0.152
#
#
# Topic 127
# DevOps               0.231
# "                    0.229
# deliver              -0.201
# Our                  0.190
# enterprise           0.187
# QA                   -0.186
# drive                0.172
# existing             -0.158
# engineers            0.152
# mobile               0.151
#
#
# Topic 128
# both                 -0.295
# "                    0.259
# Java                 0.193
# maintain             0.183
# industry             0.171
# cloud                -0.168
# people               -0.166
# issues               0.161
# into                 0.153
# market               0.147
#
#
# Topic 129
# implementation       0.233
# user                 0.223
# mobile               -0.220
# DevOps               0.216
# professional         0.161
# various              -0.159
# global               0.156
# training             0.142
# analytics            -0.142
# integration          -0.141
#
#
# Topic 130
# service              -0.219
# cloud                0.195
# deliver              -0.193
# issues               -0.193
# maintain             -0.183
# reporting            0.182
# experience.          0.173
# "                    0.162
# Develop              0.159
# this                 -0.158
#
#
# Topic 131
# "                    -0.484
# various              0.259
# maintain             0.225
# people               -0.212
# manage               -0.192
# experience.          -0.183
# issues               -0.179
# industry             0.177
# deliver              0.173
# implementation       0.131
#
#
# Topic 132
# implementation       -0.259
# engineers            0.253
# As                   -0.208
# training             -0.199
# existing             0.186
# program              0.170
# industry             -0.162
# improve              0.158
# into                 -0.139
# production           -0.127
#
#
# Topic 133
# strong               -0.376
# experience.          0.281
# existing             -0.207
# market               0.202
# program              -0.166
# this                 -0.162
# etc.                 -0.156
# solution             0.147
# Oracle               -0.122
# -_30+_days_ago       0.116
#
#
# Topic 134
# service              0.245
# various              0.241
# enterprise           -0.209
# program              -0.198
# Familiarity_with     0.187
# "                    0.178
# both                 0.165
# analysis             -0.164
# etc.                 -0.161
# As                   -0.146
#
#
# Topic 135
# "                    -0.453
# existing             0.246
# experience.          0.230
# automation           -0.190
# maintain             -0.183
# both                 -0.180
# Java                 0.168
# required.            -0.153
# code                 -0.140
# implement            0.138
#
#
# Topic 136
# global               0.230
# issues               0.215
# cloud                0.204
# Familiarity_with     0.193
# manage               -0.182
# As                   -0.179
# mobile               0.175
# delivery             0.164
# maintain             0.160
# into                 -0.146
#
#
# Topic 137
# issues               0.314
# service              -0.278
# architecture         0.215
# manage               -0.175
# DevOps               0.169
# maintain             -0.150
# AWS                  0.144
# existing             0.141
# Develop              0.127
# managing             -0.122
#
#
# Topic 138
# strong               -0.385
# both                 0.228
# architecture         0.221
# existing             0.206
# various              -0.174
# industry             0.163
# Java                 -0.145
# future               0.141
# perform              -0.139
# "                    0.138
#
#
# Topic 139
# Familiarity_with     -0.332
# implementation       0.312
# architecture         -0.216
# various              0.190
# processes            -0.162
# existing             0.157
# Develop              -0.147
# professional         -0.130
# service              -0.128
# maintain             0.122
#
#
# Topic 140
# service              -0.403
# strong               -0.277
# issues               -0.248
# As                   -0.184
# cloud                -0.154
# Oracle               0.143
# drive                0.141
# key                  -0.133
# engineers            0.122
# lead                 0.108
#
#
# Topic 141
# A                    -0.270
# existing             0.235
# make                 0.233
# etc.                 0.205
# enterprise           0.205
# industry             0.197
# understanding        -0.187
# "                    0.178
# digital              -0.135
# architecture         -0.127
#
#
# Topic 142
# professional         -0.297
# improve              0.246
# Our                  0.159
# implementation       -0.156
# both                 -0.153
# mobile               0.149
# managing             0.147
# deliver              -0.144
# client               0.141
# employees            -0.130
#
#
# Topic 143
# industry             -0.267
# experience.          0.188
# web                  -0.184
# professional         0.172
# employees            -0.170
# existing             -0.163
# make                 0.153
# global               0.148
# Familiarity_with     -0.147
# solution             -0.141
#
#
# Topic 144
# etc.                 0.442
# various              -0.288
# maintain             0.221
# strong               -0.167
# employees            0.143
# mobile               0.142
# Familiarity_with     -0.134
# automation           -0.133
# training             -0.130
# like                 0.129
#
#
# Topic 145
# industry             0.356
# architecture         0.265
# needs                -0.180
# training             -0.164
# production           0.153
# Familiarity_with     -0.130
# existing             -0.125
# strong               0.123
# QA                   -0.123
# engineers            -0.122
#
#
# Topic 146
# etc.                 -0.270
# professional         0.263
# training             -0.191
# solution             -0.165
# this                 0.165
# strong               -0.164
# A                    -0.159
# architecture         -0.152
# enterprise           0.151
# web                  -0.138
#
#
# Topic 147
# training             -0.239
# Java                 -0.217
# experience.          -0.217
# both                 -0.200
# Familiarity_with     0.187
# implementation       0.186
# cloud                -0.179
# DevOps               0.174
# various              -0.170
# make                 0.152
#
#
# Topic 148
# strong               -0.242
# web                  0.237
# Java                 0.211
# enterprise           -0.203
# A                    -0.201
# digital              0.199
# professional         -0.190
# implementation       0.164
# etc.                 -0.139
# automation           0.131
#
#
# Topic 149
# web                  -0.290
# industry             0.262
# production           -0.193
# existing             0.179
# integration          0.159
# Engineering          -0.147
# digital              0.144
# Java                 0.136
# analytics            0.131
# this                 0.131
#
#
# Topic 150
# implement            -0.322
# -_30+_days_ago       -0.226
# existing             0.189
# Design               -0.184
# ago                  0.178
# Develop              0.171
# web                  0.158
# financial            -0.153
# professional         0.150
# meet                 -0.147
#
#
# Topic 151
# improve              -0.233
# delivery             0.229
# implementation       -0.219
# QA                   -0.200
# make                 0.198
# issues               -0.185
# understanding        0.166
# user                 -0.144
# SQL                  0.139
# lead                 -0.134
#
#
# Topic 152
# problems             -0.218
# needs                0.211
# this                 -0.194
# industry             0.171
# Data                 -0.168
# deliver              -0.143
# delivery             0.143
# analysis             0.129
# QA                   -0.125
# architecture         -0.124
#
#
# Topic 153
# manage               0.253
# digital              -0.233
# enterprise           -0.232
# key                  -0.192
# delivery             -0.186
# leading              -0.161
# implement            -0.157
# web                  0.152
# architecture         0.152
# cloud                0.150
#
#
# Topic 154
# make                 0.229
# solution             -0.219
# implement            -0.195
# web                  -0.183
# A                    0.157
# understanding        -0.151
# relevant             0.149
# enterprise           0.149
# code                 0.148
# leading              -0.142
#
#
# Topic 155
# improve              0.269
# ago                  0.258
# -_30+_days_ago       -0.209
# training             -0.166
# web                  -0.156
# integration          0.154
# Support              0.151
# financial            -0.142
# experience.          -0.134
# digital              0.124
#
#
# Topic 156
# various              -0.321
# training             0.251
# will_be              0.234
# key                  0.204
# people               0.192
# into                 -0.171
# issues               -0.168
# -_30+_days_ago       -0.143
# digital              -0.137
# client               -0.120
#
#
# Topic 157
# market               0.214
# cloud                -0.196
# manage               -0.162
# A                    -0.158
# delivery             -0.150
# global               -0.147
# digital              -0.145
#                     0.144
# -_30+_days_ago       0.138
# user                 0.137
#
#
# Topic 158
# QA                   -0.251
# DevOps               -0.223
# features             -0.192
# market               -0.184
# people               -0.180
# digital              0.162
# web                  -0.157
# automation           0.154
# opportunity          0.149
# integration          0.145
#
#
# Topic 159
# integration          -0.230
# Familiarity_with     0.219
# make                 -0.192
# leading              -0.177
# client               0.173
# clients              -0.165
# organization         0.164
# key                  0.164
# A                    -0.152
# web                  -0.150
#
#
# Topic 160
# implement            0.265
# digital              -0.245
# -_30+_days_ago       -0.218
# understand           -0.186
# Familiarity_with     0.176
# QA                   -0.173
# solution             0.173
# make                 0.154
# existing             -0.129
# integration          0.128
#
#
# Topic 161
# market               -0.273
# clients              0.195
# multiple             0.180
# understand           -0.173
# professional         -0.161
# delivery             -0.159
# key                  0.151
# service              0.143
# perform              -0.128
# DevOps               0.126
#
#
# Topic 162
# Engineering          0.271
# digital              -0.269
# implement            -0.226
# delivery             0.185
# lead                 0.183
# market               -0.164
# key                  -0.163
# training             -0.156
# Familiarity_with     0.148
# organization         0.144
#
#
# Topic 163
# experience.          0.265
# professional         -0.228
# organization         0.217
# Data                 0.181
# manage               -0.168
# implement            0.166
# production           -0.147
# this                 0.147
# architecture         -0.143
# key                  -0.135
#
#
# Topic 164
# will_be              0.368
# production           -0.220
# perform              0.148
# client               -0.141
# issues               0.139
# features             -0.131
# meet                 -0.122
# service              0.121
# cloud                -0.118
# program              0.116
#
#
# Topic 165
# improve              -0.261
# lead                 0.252
# SQL                  0.224
# cloud                0.216
# delivery             -0.184
# QA                   0.177
# training             -0.148
# web                  -0.138
# program              0.135
# automation           -0.132
#
#
# Topic 166
# integration          -0.191
# a_plus.              0.190
# We_are               0.179
# SQL                  -0.170
# improve              -0.157
#                     -0.148
# analytics            0.148
# solution             0.144
# opportunity          0.142
# managing             -0.140
#
#
# Topic 167
# understanding        0.299
# integration          -0.215
# delivery             -0.191
# production           -0.188
# operations           -0.172
# best                 -0.166
# features             -0.159
# implementation       0.158
# digital              0.153
# global               -0.141
#
#
# Topic 168
# industry             0.210
# integration          0.201
# key                  0.196
# understanding        0.181
# has                  -0.174
# improve              0.160
# ...
# collaboration        0.104
# PS                   0.096
# data_center          -0.096
# API                  -0.095
#
#
# Topic 450
# Expertise            0.165
# data,                -0.137
# while                -0.122
# (e.g.                0.119
# â€¢                  -0.118
# C++                  0.104
# partner              0.104
# partners             -0.099
# end                  0.099
# effective            0.098
#
#
# Topic 451
# effectively          -0.141
# plans                -0.139
# vision               -0.138
# (e.g.,               0.122
# consumer             -0.108
# background           -0.106
# creative             0.104
# â€¢                  0.101
# Engineer             0.100
# Expertise            -0.096
#
#
# Topic 452
# management,          -0.128
# tools,               -0.122
# initiatives          -0.114
# modern               -0.113
# detail               0.107
# minimum              -0.104
# team_members         0.101
# networking           0.092
# partner              0.092
# collaborate          0.091
#
#
# Topic 453
# â€¢                  0.193
# Engineer             -0.165
# Expertise            0.155
# or_equivalent        -0.135
# analysis,            0.116
# review               -0.112
# practices            -0.112
# Technical            0.106
# API                  -0.105
# group                -0.100
#
#
# Topic 454
#                     0.144
# successful           0.110
# iOS                  0.106
# Services             0.101
# Perform              -0.101
# coding               0.100
# major                -0.097
# 5_years              0.097
# strategic            -0.094
# requirements,        -0.094
#
#
# Topic 455
# â€¢                  -0.144
# power                -0.108
# storage              0.107
# is_looking_for       -0.106
# 3_years              0.098
# communication        -0.097
# area                 -0.095
# companies            0.094
# Minimum              -0.093
# manufacturing        0.090
#
#
# Topic 456
# (e.g.,               -0.168
# environments         -0.137
# data.                -0.118
# those                0.106
# member               -0.105
# end                  -0.102
# Windows              0.101
# engineer             0.099
# Services             -0.097
# good                 0.094
#
#
# Topic 457
# Work_closely_with    -0.153
# services.            0.134
# City                 0.118
# analyze              0.115
# companies            0.115
# good                 -0.112
# changes              0.109
# planning             0.108
# Must_be_able         0.098
# area                 0.095
#
#
# Topic 458
# â€¢                  0.159
# tools,               0.138
# culture              -0.116
# experience,          -0.115
# Perform              -0.111
# right                -0.109
# about                0.108
# engineer             0.106
# risk                 0.104
# bring                0.099
#
#
# Topic 459
#                     0.128
# services.            -0.113
# experiences          0.112
# used                 0.104
# SAP                  0.103
# many                 0.103
# â€¢                  0.100
# apply                -0.096
# over                 0.092
# contribute           0.091
#
#
# Topic 460
# data.                0.118
# strategies           -0.115
# review               -0.114
# different            -0.108
# power                -0.106
# successful           -0.103
# us                   -0.102
# insights             0.100
# Demonstrated_experience -0.098
# Security             0.096
#
#
# Topic 461
# millions             -0.125
# efforts              -0.112
# Software_Engineer    -0.098
# us                   -0.097
# end                  -0.097
# Technical            -0.095
# manufacturing        -0.094
# methods              0.094
# At                   0.088
# API                  0.087
#
#
# Topic 462
# â€¢                  0.164
# good                 0.134
# (e.g.,               0.132
# bring                0.105
# learn                0.097
# or_equivalent        0.096
# API                  -0.093
# scalable             -0.091
# next_generation      0.090
# Expertise            -0.086
#
#
# Topic 463
# â€¢                  -0.228
# Manager              -0.123
# focus_on             -0.118
# end                  -0.115
# bring                0.113
# SAP                  0.111
# teams.               -0.111
# assist               -0.102
# small                0.098
# effectively          -0.092
#
#
# Topic 464
# â€¢                  -0.134
# data.                0.123
# Be                   0.114
# responsible_for      -0.107
# leader               -0.106
# computer             -0.096
# Required             0.095
# dynamic              -0.094
# control              0.092
# engineer             0.090
#
#
# Topic 465
# area                 0.132
# effective            0.120
# Windows              -0.117
# storage              -0.112
# Manager              0.111
# document             -0.108
# Maintain             -0.106
# systems,             -0.105
# data_analysis        -0.104
# experiences          -0.099
#
#
# Topic 466
# complete             -0.145
# PS                   0.130
# Demonstrated_experience 0.119
# them                 -0.110
# teams.               -0.103
# components           -0.102
# You_will_be          -0.101
# To                   0.099
# United               -0.099
# goals                0.095
#
#
# Topic 467
# tools,               -0.114
# collaboration        -0.109
# â€¢                  0.109
# functions            0.108
# change               0.096
# experience,          -0.096
# API                  -0.094
# Maintain             0.092
# manufacturing        -0.091
# scalable             -0.090
#
#
# Topic 468
# products,            -0.113
# computer             0.107
# Required             0.104
# background           -0.103
# databases            -0.101
# Services             0.096
# goals                -0.095
# storage              -0.093
# Systems              -0.091
# Technical            0.091
#
#
# Topic 469
# communication        -0.164
# (e.g.,               0.119
# or_equivalent        -0.119
# United               -0.114
# successful           0.102
# dynamic              -0.101
# associated           0.100
# throughout           -0.095
# experience,          0.092
# not                  -0.088
#
#
# Topic 470
# PS                   0.166
# BU                   0.131
# consumer             0.130
# engineer             0.129
# while                0.116
# culture              0.109
# experience,          0.100
# creative             -0.096
# (e.g.                -0.087
# do                   0.086
#
#
# Topic 471
# iOS                  -0.130
# Test                 -0.114
# C++                  -0.110
# This_position        -0.109
# data.                -0.102
# teams.               0.101
# collaborate          -0.100
# â€¢                  0.098
# change               0.095
# We_have              0.090
#
#
# Topic 472
# practices            -0.131
# available            0.130
# engineer             -0.106
# Demonstrated_ability 0.104
# data_analysis        -0.100
# About                0.098
# online               -0.096
# requirements,        -0.095
# data,                -0.093
# 5_years              0.092
#
#
# Topic 473
# â€¢                  -0.155
# development.         0.147
# driving              0.120
# projects.            0.102
# learn                -0.097
# end                  -0.094
# while                0.093
# or_similar           -0.090
# Windows              -0.089
# initiatives          0.088
#
#
# Topic 474
# customers.           0.158
# United               -0.128
# Expertise            0.111
# area                 0.110
# Work_closely_with    -0.106
# computer             0.101
# companies            -0.101
# tasks                0.100
# teams.               0.098
# take                 0.098
#
#
# Topic 475
# planning             0.132
# throughout           -0.129
# world                0.105
# teams.               -0.105
# plans                -0.099
# US                   0.097
# Systems              -0.092
# Demonstrated_experience -0.090
# This_position        -0.090
# ideas                0.086
#
#
# Topic 476
# products,            0.139
# portfolio            -0.120
# video                -0.115
# making               -0.102
# focus_on             0.095
# PS                   -0.095
# be_able              -0.093
# creative             -0.090
# do                   0.087
# (e.g.,               -0.086
#
#
# Topic 477
# analysis,            -0.166
# do                   0.123
# execution            0.116
# benefits             -0.112
# 1_year               0.109
# â€¢                  0.105
# procedures           0.101
# member               0.095
# services.            -0.092
# or_equivalent        -0.091
#
#
# Topic 478
# engineer             0.127
# member               -0.120
# Demonstrated_experience 0.117
# PS                   -0.117
# plans                -0.113
# right                -0.112
# good                 -0.111
# apply                -0.109
# â€¢                  -0.105
# throughout           -0.103
#
#
# Topic 479
# United               0.132
# Windows              -0.111
# Demonstrated_experience -0.109
# teams,               -0.105
# customers.           -0.099
# detail               0.098
# days_ago             -0.097
# Expertise            0.097
# video                -0.094
# making               0.093
#
#
# Topic 480
# modern               -0.116
# databases            0.112
# good                 0.108
# during               0.104
# distributed          0.103
# community            0.101
# video                -0.101
# assist               0.100
# Software_Engineer    0.100
# methods              0.100
#
#
# Topic 481
# right                0.123
# data_science         -0.116
# external             -0.116
# next_generation      0.116
# You_will_be          0.115
# US                   0.112
# change               0.111
# is_an_Equal          0.105
# server               -0.102
# projects.            -0.097
#
#
# Topic 482
# experience,          -0.138
# To                   0.117
# collaboration        0.112
# changes              0.111
# challenges           0.109
# Analytics            0.096
# potential            0.093
# we_are               0.091
# risk                 0.091
# Management           0.089
#
#
# Topic 483
# education            0.144
# (e.g.,               -0.120
# resources            -0.114
# video                0.105
# engineer             -0.105
# while                0.104
# Manager              -0.102
# we_are               -0.102
# United               -0.097
# execute              0.092
#
#
# Topic 484
# engineer             0.111
# Test                 0.109
# Enterprise           0.106
# power                0.102
# control              -0.099
# area                 -0.097
# background           0.094
# This                 -0.091
# SaaS                 -0.090
# Technical            -0.090
#
#
# Topic 485
# agile                0.106
# over                 -0.103
# (e.g.,               -0.100
# engineer             -0.098
# different            0.098
# better               -0.097
# us                   -0.095
# resources            0.094
# United               -0.093
# API                  0.091
#
#
# Topic 486
# â€¢                  0.147
# (e.g.                0.118
# launch               -0.107
#                     -0.105
# effective            -0.104
# To                   -0.098
# small                -0.098
# products,            -0.096
# modern               0.092
# ideas                0.089
#
#
# Topic 487
# collaborate          -0.114
# metrics              -0.112
# achieve              0.108
#                     -0.108
# creative             -0.107
# PS                   -0.103
# 5_years              0.099
# culture              -0.098
# focus_on             -0.097
# goals                -0.096
#
#
# Topic 488
# Enterprise           -0.141
# iOS                  0.111
# Technical            -0.099
# document             -0.096
# databases            0.095
# resources            0.093
# written              0.091
# metrics              0.088
# SaaS                 -0.087
# frameworks           -0.083
#
#
# Topic 489
# initiatives          -0.117
# Be                   -0.111
# requirements.        0.107
# bring                0.105
# customers.           0.105
# This_position        -0.103
# document             -0.103
# â€¢                  0.102
# apply                0.101
# review               0.097
#
#
# Topic 490
# projects.            -0.118
# iOS                  -0.096
# ideas                0.096
# Technical            -0.094
# local                0.091
# big_data             0.090
# Qualifications       0.090
# competitive          0.090
# collaborate          0.088
# requirements.        0.085
#
#
# Topic 491
# available            -0.118
# Minimum              -0.105
# frameworks           -0.100
# Manager              -0.094
# metrics              0.093
# services.            -0.091
# databases            0.090
# collaboration        -0.088
# consumer             -0.087
# 1_year               0.087
#
#
# Topic 492
# developer            0.116
# partner              -0.102
# collaborate          -0.096
# effective            -0.096
# out                  0.093
# small                -0.089
# Qualifications       0.084
# scalable             -0.083
# being                0.083
# Collaborate_with     0.083
#
#
# Topic 493
#                     -0.144
# requirements.        0.123
# initiatives          0.114
# United               0.112
# online               -0.111
# unique               0.111
# changes              -0.100
# 3_years              0.098
# data_analysis        0.096
# Technical            -0.092
#
#
# Topic 494
# United               0.147
# Required             -0.128
# used                 -0.105
# modern               -0.103
# risk                 0.100
# et                   0.099
# Expertise            -0.096
# making               -0.095
# as_part              0.092
# background           -0.089
#
#
# Topic 495
# PS                   -0.135
# iOS                  0.124
# â€¢                  0.122
# To                   -0.108
# BU                   -0.106
# Demonstrated_experience 0.100
# strategies           0.099
# execute              -0.097
# Enterprise           0.095
# utilizing            -0.094
#
#
# Topic 496
# Technology           0.121
# assist               0.120
# To                   0.118
# decisions            0.113
# â€¢                  -0.107
# simulation           -0.106
# Ensure               -0.102
# utilizing            -0.095
# driving              -0.094
# them                 0.091
#
#
# Topic 497
# United               0.165
# PS                   0.160
# To                   -0.140
# Demonstrated_experience 0.133
# BU                   0.124
# Services             -0.107
# Technical            0.106
# external             0.103
# community            -0.102
# What                 0.097
#
#
# Topic 498
# assist               -0.116
# Web                  0.105
# 3_years              0.105
# UI                   -0.103
# degree               -0.101
# small                0.097
# Engineer             0.095
# background           0.091
# iOS                  -0.089
# §                    -0.089
#
#
# Topic 499
# United               -0.133
# simulation           -0.132
# networking           0.123
# Required             -0.115
# document             -0.109
# Work_closely_with    -0.105
# server               0.102
# health               -0.095
# department           0.092
# own                  0.091
#
#
# Topic 500
# successful           -0.121
# Systems              -0.109
# others               -0.107
# execute              0.102
# effective            -0.102
# Enterprise           0.101
# Windows              0.087
# game                 -0.087
# developer            -0.083
# frameworks           -0.083
#
#
# Topic 501
#
#
# Topic 502
#
#
# Topic 503
#
#
# Topic 504
#
#
# Topic 505
#
#
# Topic 506
#
#
# Topic 507
#
#
# Topic 508
#
#
# Topic 509
#
#
# Topic 510
#
#
# Topic 511
#
#
# Topic 512
#
#
# Topic 513
#
#
# Topic 514
#
#
# Topic 515
#
#
# Topic 516
#
#
# Topic 517
#
#
# Topic 518
#
#
# Topic 519
#
#
# Topic 520
#
#
# Topic 521
#
#
# Topic 522
#
#
# Topic 523
#
#
# Topic 524
#
#
# Topic 525
#
#
# Topic 526
#
#
# Topic 527
#
#
# Topic 528
#
#
# Topic 529
#
#
# Topic 530
#
#
# Topic 531
#
#
# Topic 532
#
#
# Topic 533
#
#
# Topic 534
#
#
# Topic 535
#
#
# Topic 536
#
#
# Topic 537
#
#
# Topic 538
#
#
# Topic 539
#
#
# Topic 540
#
#
# Topic 541
#
#
# Topic 542
#
#
# Topic 543
#
#
# Topic 544
#
#
# Topic 545
#
#
# Topic 546
#
#
# Topic 547
#
#
# Topic 548
#
#
# Topic 549
#
#
# Topic 550
#
#
# Topic 551
#
#
# Topic 552
#
#
# Topic 553
#
#
# Topic 554
#
#
# Topic 555
#
#
# Topic 556
#
#
# Topic 557
#
#
# Topic 558
#
#
# Topic 559
#
#
# Topic 560
#
#
# Topic 561
#
#
# Topic 562
#
#
# Topic 563
#
#
# Topic 564
#
#
# Topic 565
#
#
# Topic 566
#
#
# Topic 567
#
#
# Topic 568
#
#
# Topic 569
#
#
# Topic 570
#
#
# Topic 571
#
#
# Topic 572
#
#
# Topic 573
#
#
# Topic 574
#
#
# Topic 575
#
#
# Topic 576
#
#
# Topic 577
#
#
# Topic 578
#
#
# Topic 579
#
#
# Topic 580
#
#
# Topic 581
#
#
# Topic 582
#
#
# Topic 583
#
#
# Topic 584
#
#
# Topic 585
#
#
# Topic 586
#
#
# Topic 587
#
#
# Topic 588
#
#
# Topic 589
#
#
# Topic 590
#
#
# Topic 591
#
#
# Topic 592
#
#
# Topic 593
#
#
# Topic 594
#
#
# Topic 595
#
#
# Topic 596
#
#
# Topic 597
#
#
# Topic 598
#
#
# Topic 599
#
#
# Topic 600

# %% [markdown]
# ## SpaCy, this time using a corpus that only consists of skill-phrases

# %%
# %%time
# Note that the data itself (line 9) is not "original_texts", which is the raw text;
# it's "parsed_dataset", which is the collection of POS-tagged skill-phrases

import codecs
# This is time consuming; make the if statement True to run
if 0 == 0:
    with codecs.open('spacy_jds_concat_parsed_POS.txt', 'w', encoding='utf_8') as f:
        for sentence in parsed_dataset:
            f.write(sentence + '\n')
# Out:
# CPU times: user 146 ms, sys: 36.1 ms, total: 182 ms
# Wall time: 183 ms

# %%
unigram_sentences = LineSentence('spacy_jds_concat_parsed_POS.txt')

# %%
# %%time

bigram_model = Phrases(unigram_sentences)
bigram_model.save('spacy_bigram_model_all_PARSED_POS')
# Out:
# /usr/local/lib/python3.6/site-packages/gensim/models/phrases.py:317: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if all(parameter in getargspec(scoring)[0] for parameter in scoring_parameters):
# /usr/local/lib/python3.6/site-packages/gensim/models/phrases.py:317: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if all(parameter in getargspec(scoring)[0] for parameter in scoring_parameters):
# /usr/local/lib/python3.6/site-packages/gensim/models/phrases.py:317: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if all(parameter in getargspec(scoring)[0] for parameter in scoring_parameters):
# /usr/local/lib/python3.6/site-packages/gensim/models/phrases.py:317: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if all(parameter in getargspec(scoring)[0] for parameter in scoring_parameters):
# /usr/local/lib/python3.6/site-packages/gensim/models/phrases.py:317: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if all(parameter in getargspec(scoring)[0] for parameter in scoring_parameters):
# /usr/local/lib/python3.6/site-packages/gensim/models/phrases.py:317: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if all(parameter in getargspec(scoring)[0] for parameter in scoring_parameters):
# CPU times: user 20.9 s, sys: 284 ms, total: 21.2 s
# Wall time: 21.2 s

# %%
# load the finished model from disk
bigram_model = Phrases.load('spacy_bigram_model_all_PARSED_POS')

# %%
# %%time

with codecs.open('spacy_bigram_sentences_PARSED_POS.txt', 'w', encoding='utf_8') as f:
    for unigram_sentence in unigram_sentences:
        bigram_sentence = u' '.join(bigram_model[unigram_sentence])
        f.write(bigram_sentence + '\n')
# Out:
# /usr/local/lib/python3.6/site-packages/gensim/models/phrases.py:486: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")
# CPU times: user 41.4 s, sys: 212 ms, total: 41.7 s
# Wall time: 41.9 s

# %%
bigram_sentences = LineSentence('spacy_bigram_sentences_PARSED_POS.txt')

# %%
# print examples; certain bigrams are underlined
# for bigram_sentence in it.islice(bigram_sentences, 240, 250):
#     print(u' '.join(bigram_sentence))
#     print(u'')

# %%
# %%time
trigram_model = Phrases(bigram_sentences)
trigram_model.save('spacy_trigram_model_all_PARSED_POS')
# Out:
# /usr/local/lib/python3.6/site-packages/gensim/models/phrases.py:317: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if all(parameter in getargspec(scoring)[0] for parameter in scoring_parameters):
# /usr/local/lib/python3.6/site-packages/gensim/models/phrases.py:317: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if all(parameter in getargspec(scoring)[0] for parameter in scoring_parameters):
# /usr/local/lib/python3.6/site-packages/gensim/models/phrases.py:317: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if all(parameter in getargspec(scoring)[0] for parameter in scoring_parameters):
# /usr/local/lib/python3.6/site-packages/gensim/models/phrases.py:317: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if all(parameter in getargspec(scoring)[0] for parameter in scoring_parameters):
# /usr/local/lib/python3.6/site-packages/gensim/models/phrases.py:317: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if all(parameter in getargspec(scoring)[0] for parameter in scoring_parameters):
# /usr/local/lib/python3.6/site-packages/gensim/models/phrases.py:317: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if all(parameter in getargspec(scoring)[0] for parameter in scoring_parameters):
# CPU times: user 20.8 s, sys: 305 ms, total: 21.1 s
# Wall time: 21.1 s

# %%
# load the finished model from disk
trigram_model = Phrases.load('spacy_trigram_model_all_PARSED_POS')

# %%
# %%time

with codecs.open('spacy_trigram_sentences_PARSED_POS.txt', 'w', encoding='utf_8') as f:
    for bigram_sentence in bigram_sentences:
        trigram_sentence = u' '.join(trigram_model[bigram_sentence])
        f.write(trigram_sentence + '\n')
# Out:
# /usr/local/lib/python3.6/site-packages/gensim/models/phrases.py:486: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")
# CPU times: user 37.4 s, sys: 246 ms, total: 37.6 s
# Wall time: 38 s

# %%
trigram_sentences = LineSentence('spacy_trigram_sentences_PARSED_POS.txt')

# %%
# for trigram_sentence in it.islice(trigram_sentences, 240, 250):
#     print(u' '.join(trigram_sentence))
#     print(u'')

# %% [markdown]
# #### Final preprocessing

# %%
# %%time

with codecs.open('spacy_trigram_transformed_jds_all_PARSED_POS.txt', 'w', encoding='utf_8') as f:
    for parsed_review in nlp.pipe(line_review(original_texts),
                                  batch_size=10000, n_threads=4):
        # lemmatize the text, removing punctuation and whitespace
        unigram_review = [token.lemma_ for token in parsed_review
                          if not punct_space(token)]

        # apply the first-order and second-order phrase models
        bigram_review = bigram_model[unigram_review]
        trigram_review = trigram_model[bigram_review]

        # remove any remaining stopwords
        trigram_review = [term for term in trigram_review
                          if term not in stopwords]

        # write the transformed review as a line in the new file
        trigram_review = u' '.join(trigram_review)
        f.write(trigram_review + '\n')
# Out:
# /usr/local/lib/python3.6/site-packages/gensim/models/phrases.py:486: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")
# CPU times: user 1h 39min 13s, sys: 1h 46min 23s, total: 3h 25min 37s
# Wall time: 2h 47min 42s

# %%
print(u'Original:' + u'\n')

for review in it.islice(line_review(original_texts), 11, 12):
    print(review)

print(u'----' + u'\n')
print(u'Transformed:' + u'\n')

with codecs.open('spacy_trigram_transformed_jds_all_PARSED_POS.txt', encoding='utf_8') as f:
    for review in it.islice(f, 11, 12):
        print(review)
# Out:
# Original:
#
# Position Overview  Are you a full stack Software Engineer looking for an opportunity to work in a fast paced and fun environment? Then consider joining us here at Skillsoft in Rochester, NY. We are building SaaS platforms and client applications for our content delivery products with the goal of being the “best in the industry”. Our products allow 6000+ customers consume content from a variety of sources with a strong focus on video, from any device, with features that fit the needs of learner. We believe that our customers deserve the best learning experiences and we are delivering on those needs with the products you will be working on. You could be the one to help us achieve this goal!  We are looking for exceptional developers to join our team and willing to learn new technology in this rapidly evolving world. You will build front end customer facing product features using cutting edge technologies while implementing REST APIs and other back-end functionality as needed.  Position Responsibilities    Build reusable code and libraries for future use  Ensure the technical feasibility of UI/UX designs  Optimize user-facing features for maximum speed and scalability  Collaborate with other team members and stakeholders to build user-facing features  Build prototypes and turn them into real production-quality features  Implement backend functionality as needed, such as REST APIs  Knowledge and Skills    Minimum of 3+ years of experience in web development – primarily on the front end using JavaScript, HTML5, and/or CSS3  Experience with Java and REST  Strong skills in JavaScript and using an MVW framework (React, Angular, Meteor, etc)  Experience with React and Redux or any modern JS framework (Ember, Angular, etc)  Experience with automation tools such as Npm, Webpack, Grunt, Bower etc.  Experience with code versioning tools, preferably Git (Github, Gitlab, etc) and the feature branch workflow  Proficient building responsive cross browser UI’s and exposure to mobile development  Experience of either SASS or LESS pre-processor  Experience in UI Test frameworks (CasperJS, PhantomJS, Mocha, Jasmine, JEST, Selenium, etc.)  Experience working in an Agile/Scrum environment  Demonstrated ability to ship code in production  Passionate, curious and open to new ideas  Education and Certifications  BS in Computer Science Preferred  Submit Profile  SumTotal Systems  -  30+ days ago
# ----
#
# Transformed:
#
# position_overview -PRON- full_stack software engineer look opportunity work fast_paced and_fun environment consider join -PRON- skillsoft rochester_ny -PRON- build saas platform client application -PRON- content delivery product goal good industry -PRON- product allow 6000 + customer consume content variety source strong focus video device feature fit need learner -PRON- believe -PRON- customer deserve good learning experience -PRON- deliver need product -PRON- work -PRON- could one help -PRON- achieve goal -PRON- look exceptional developer join -PRON- team willing learn new technology rapidly evolve world -PRON- build front_end customer face product feature use cut edge technology implement rest_api back_end functionality need position responsibilities build_reusable_code library future use ensure technical feasibility ui_ux design optimize user face feature maximum_speed scalability collaborate team_member stakeholder build user face feature build prototype turn -PRON- real production quality feature implement backend functionality need rest_api knowledge skills minimum 3 + year experience web development primarily front_end use javascript_html5 and/or css3 experience java rest strong skill javascript use mvw framework_react_angular meteor etc experience react redux modern js framework_ember_angular etc experience automation tool npm_webpack grunt_bower etc experience code version tool preferably git_github_gitlab etc feature branch workflow proficient building responsive cross_browser ui ’s exposure mobile development experience either sass less pre_processor experience ui test framework casperjs phantomjs mocha_jasmine jest selenium etc experience work agile_scrum environment demonstrate ability ship code production passionate_curious open new idea education certifications bs computer_science preferred submit profile sumtotal systems 30 + day ago

# %%
# %%time

trigram_reviews = LineSentence('spacy_trigram_sentences_PARSED_POS.txt')

# learn the dictionary by iterating over all of the reviews
trigram_dictionary = Dictionary(trigram_reviews)

# filter tokens that are very rare or too common from
# the dictionary (filter_extremes) and reassign integer ids (compactify)
trigram_dictionary.filter_extremes(no_below=10, no_above=0.4)
trigram_dictionary.compactify()

trigram_dictionary.save('spacy_trigram_dict_all_POS.dict')
    
# load the finished dictionary from disk
trigram_dictionary = Dictionary.load('spacy_trigram_dict_all_POS.dict')
# Out:
# CPU times: user 7.83 s, sys: 178 ms, total: 8.01 s
# Wall time: 8.22 s

# %%
def trigram_bow_generator(filepath):
    """
    generator function to read reviews from a file
    and yield a bag-of-words representation
    """    
    for review in LineSentence(filepath):
        yield trigram_dictionary.doc2bow(review)

# %%
# %%time

# generate bag-of-words representations for all JDs and save them as a matrix
MmCorpus.serialize('spacy_trigram_bow_corpus_all_POS.mm',
                   trigram_bow_generator('spacy_trigram_sentences_PARSED_POS.txt'))
    
# load the finished bag-of-words corpus from disk
trigram_bow_corpus = MmCorpus('spacy_trigram_bow_corpus_all_POS.mm')
# Out:
# CPU times: user 11.8 s, sys: 135 ms, total: 11.9 s
# Wall time: 12 s

# %% [markdown]
# ### Modeling

# %%
# %%time

with warnings.catch_warnings():
    warnings.simplefilter('ignore')

    # workers => sets the parallelism, and should be
    # set to your number of physical cores minus one
    lsi = gensim.models.LsiModel(trigram_bow_corpus, 
                                 id2word=trigram_dictionary, 
                                 num_topics=50)
    
    lsi.save('spacy_lsi_model_all_POS')
# Out:
# CPU times: user 20.7 s, sys: 662 ms, total: 21.4 s
# Wall time: 16.7 s

# %%
# load the finished LDA model from disk
lsi = LsiModel.load('spacy_lsi_model_all_POS')

# %%
def explore_topic(topic_number, topn=10):
    """
    accept a user-supplied topic number and
    print out a formatted list of the top terms
    """
        
#     print(u'{:20} {}'.format(u'term', u'frequency') + u'')

    for term, frequency in lsi.show_topic(topic_number, topn=60):
        print(u'{:20} {:.3f}'.format(term, round(frequency, 3)))

# %%
for i in range(50):
    print("\n\nTopic %s" % str(i+1))
    explore_topic(topic_number=i)
# Out:
# Topic 1
# sale                 0.179
# support              0.178
# client               0.152
# position             0.144
# platform             0.135
# information          0.134
# analysis             0.133
# ’s                   0.130
# program              0.130
# knowledge            0.126
# manager              0.125
# role                 0.124
# industry             0.121
# problem              0.120
# quality              0.120
# database             0.111
# user                 0.108
# marketing            0.108
# web                  0.106
# organization         0.105
# security             0.105
# test                 0.104
# performance          0.101
# level                0.100
# or                   0.100
# need                 0.098
# strategy             0.097
# market               0.096
# practice             0.095
# cloud                0.093
# people               0.093
# partner              0.091
# research             0.090
# job                  0.089
# complex              0.089
# professional         0.086
# issue                0.085
# employee             0.085
# operation            0.084
# plan                 0.083
# time                 0.083
# year                 0.081
# analytics            0.080
# architecture         0.080
# implementation       0.078
# understanding        0.076
# infrastructure       0.076
# standard             0.075
# key                  0.075
# enterprise           0.074
# developer            0.073
# multiple             0.072
# qualification        0.070
# world                0.069
# part                 0.069
# group                0.068
# code                 0.067
# senior               0.066
# activity             0.064
# leadership           0.064
#
#
# Topic 2
# sale                 0.733
# marketing            0.285
# market               0.188
# database             -0.170
# test                 -0.156
# web                  -0.118
# platform             -0.103
# strategy             0.094
# manager              0.093
# security             -0.089
# code                 -0.088
# developer            -0.085
# cloud                -0.078
# infrastructure       -0.078
# quality              -0.078
# architecture         -0.078
# account              0.077
# practice             -0.075
# plan                 0.069
# relationship         0.068
# problem              -0.067
# industry             0.067
# user                 -0.066
# automation           -0.062
# opportunity          0.061
# presentation         0.059
# partner              0.058
# agile                -0.057
# java                 -0.057
# framework            -0.056
# standard             -0.056
# sql                  -0.056
# line                 0.052
# production           -0.051
# performance          -0.051
# training             0.049
# qa                   -0.049
# issue                -0.048
# integration          -0.047
# aws                  -0.046
# knowledge            -0.046
# analysis             -0.045
# need                 0.045
# information          -0.045
# complex              -0.044
# key                  0.042
# deployment           -0.042
# devops               -0.040
# server               -0.039
# documentation        -0.038
# familiarity          -0.038
# growth               0.037
# testing              -0.036
# launch               0.036
# strategic            0.035
# implement            -0.034
# territory            0.034
# prospect             0.034
# implementation       -0.033
# channel              0.032
#
#
# Topic 3
# database             0.425
# platform             -0.278
# support              0.254
# web                  -0.183
# user                 -0.179
# information          0.171
# cloud                -0.171
# analysis             0.153
# marketing            -0.152
# position             0.136
# program              0.131
# report               0.123
# people               -0.121
# feature              -0.117
# role                 -0.104
# mobile               -0.102
# world                -0.099
# sale                 0.090
# security             0.089
# developer            -0.088
# market               -0.088
# quality              0.083
# partner              -0.079
# ’s                   -0.078
# issue                0.076
# procedure            0.074
# digital              -0.073
# agile                -0.072
# infrastructure       -0.071
# strategy             -0.070
# performance          0.066
# analytics            -0.065
# analyst              0.065
# department           0.064
# oracle               0.064
# aws                  -0.064
# activity             0.064
# way                  -0.063
# building             -0.063
# industry             -0.062
# must                 0.062
# documentation        0.061
# training             0.061
# passion              -0.061
# staff                0.060
# reporting            0.059
# great                -0.059
# sql                  0.058
# framework            -0.057
# consumer             -0.057
# standard             0.057
# client               -0.056
# maintenance          0.056
# ux                   -0.055
# architecture         -0.055
# operation            0.053
# level                0.053
# code                 -0.053
# education            0.052
# idea                 -0.051
#
#
# Topic 4
# security             -0.387
# sale                 -0.368
# cloud                -0.279
# analysis             0.238
# research             0.204
# infrastructure       -0.185
# marketing            0.178
# database             -0.177
# program              0.158
# platform             -0.158
# quality              0.136
# user                 0.131
# network              -0.130
# analytics            0.129
# automation           -0.106
# analyst              0.105
# architecture         -0.103
# aws                  -0.102
# manager              0.099
# web                  -0.093
# devops               -0.093
# strategy             0.087
# report               0.085
# deployment           -0.085
# enterprise           -0.081
# support              -0.078
# server               -0.076
# insight              0.075
# knowledge            -0.065
# result               0.065
# code                 -0.064
# decision             0.062
# market               0.062
# plan                 0.061
# stakeholder          0.061
# reporting            0.061
# developer            -0.060
# science              0.056
# production           -0.056
# monitoring           -0.055
# java                 -0.054
# analytical           0.052
# model                0.051
# partner              0.049
# linux                -0.049
# oracle               -0.049
# need                 0.048
# account              -0.043
# client               0.043
# consumer             0.043
# year                 -0.043
# department           0.042
# data_scientist       0.041
# configuration        -0.041
# integration          -0.040
# source               0.040
# financial            0.040
# digital              0.040
# ux                   0.040
# networking           -0.039
#
#
# Topic 5
# test                 0.592
# quality              0.304
# security             -0.277
# database             -0.268
# qa                   0.177
# analytics            -0.163
# sale                 0.161
# automation           0.149
# client               -0.139
# marketing            -0.114
# analysis             -0.108
# research             -0.105
# information          -0.101
# testing              0.101
# web                  0.101
# cloud                -0.100
# quality_assurance    0.083
# user                 -0.081
# platform             -0.079
# code                 0.079
# test_automation      0.078
# test_case            0.078
# test_plan            0.072
# model                -0.071
# insight              -0.065
# framework            0.062
# partner              -0.055
# issue                0.053
# release              0.052
# big_data             -0.051
# developer            0.051
# review               0.051
# science              -0.050
# analyst              -0.049
# enterprise           -0.049
# infrastructure       -0.048
# agile                0.048
# specification        0.046
# sql                  -0.045
# position             0.045
# data_scientist       -0.045
# defect               0.044
# java                 0.044
# oracle               -0.044
# activity             0.044
# network              -0.043
# knowledge            0.042
# must                 0.040
# operation            -0.039
# equipment            0.039
# documentation        0.039
# document             0.039
# ’s                   -0.038
# methodology          0.038
# standard             0.036
# manufacturing        0.035
# integration          0.035
# visualization        -0.034
# decision             -0.033
# source               -0.033
#
#
# Topic 6
# client               -0.501
# security             0.417
# program              0.294
# marketing            0.251
# database             -0.249
# sale                 -0.219
# user                 -0.169
# web                  -0.153
# cloud                0.145
# manager              0.143
# market               0.109
# strategy             0.108
# infrastructure       0.097
# plan                 0.091
# network              0.090
# quality              0.082
# analytics            -0.081
# sql                  -0.081
# developer            -0.075
# partner              0.072
# operation            0.068
# leadership           0.062
# risk                 0.060
# problem              -0.056
# professional         -0.055
# key                  0.047
# information          0.047
# organization         0.046
# industry             -0.046
# activity             0.045
# compliance           0.045
# ux                   -0.044
# mobile               -0.043
# launch               0.041
# execution            0.041
# test                 0.041
# communication        0.041
# drive                0.041
# global               0.039
# knowledge            -0.038
# model                -0.038
# release              0.036
# science              -0.036
# hardware             0.036
# initiative           0.036
# planning             0.035
# big_data             -0.035
# manage               0.035
# account              -0.035
# line                 0.035
# code                 -0.034
# aws                  0.034
# devops               0.034
# control              0.032
# interaction          -0.031
# java                 -0.031
# research             -0.031
# review               0.030
# metric               0.030
# automation           0.029
#
#
# Topic 7
# database             -0.571
# client               0.453
# marketing            -0.372
# security             0.217
# user                 -0.170
# program              0.142
# market               -0.130
# test                 -0.127
# information          0.114
# professional         0.104
# web                  -0.102
# performance          -0.098
# strategy             -0.092
# platform             -0.087
# oracle               -0.085
# sql                  -0.074
# employee             0.067
# risk                 0.067
# feature              -0.067
# position             0.066
# network              0.066
# delivery             0.055
# content              -0.052
# financial            0.048
# production           -0.048
# sql_server           -0.042
# brand                -0.041
# launch               -0.040
# level                0.039
# implementation       0.038
# quality              0.038
# developer            -0.037
# dba                  -0.036
# consumer             -0.036
# operation            0.036
# organization         0.036
# center               0.035
# relationship         0.035
# server               -0.035
# database_administrator -0.035
# qa                   -0.034
# mobile               -0.033
# career               0.033
# compliance           0.033
# digital              -0.032
# training             0.032
# devops               0.031
# job                  0.030
# research             -0.030
# or                   0.030
# database_administration -0.029
# staff                0.029
# account              0.029
# consultant           0.029
# control              0.028
# plan                 -0.028
# manager              -0.028
# channel              -0.028
# ux                   -0.027
# sale                 -0.027
#
#
# Topic 8
# user                 -0.484
# client               0.400
# research             -0.249
# marketing            0.219
# web                  -0.206
# security             -0.182
# information          -0.178
# position             -0.152
# database             0.150
# sale                 -0.146
# analytics            0.141
# cloud                0.139
# test                 0.127
# ux                   -0.117
# strategy             0.115
# quality              0.109
# automation           0.100
# infrastructure       0.094
# mobile               -0.086
# performance          0.079
# interaction          -0.079
# market               0.070
# role                 0.069
# developer            -0.069
# designer             -0.067
# job                  -0.065
# delivery             0.065
# platform             0.064
# devops               0.064
# partner              0.059
# education            -0.058
# qa                   0.055
# global               0.055
# or                   -0.050
# sql                  0.049
# financial            0.049
# big_data             0.049
# feature              -0.046
# employee             -0.043
# release              0.042
# deployment           0.042
# issue                0.042
# computer             -0.042
# need                 -0.041
# operation            0.041
# program              -0.041
# oracle               0.040
# key                  0.040
# user_interface       -0.039
# ui                   -0.039
# model                0.039
# insight              0.038
# aws                  0.038
# idea                 -0.037
# production           0.036
# manager              0.036
# plan                 0.035
# usability            -0.035
# ux_designer          -0.035
# industry             0.034
#
#
# Topic 9
# client               0.350
# analysis             -0.345
# analytics            -0.298
# manager              0.234
# user                 0.219
# program              0.207
# sale                 -0.203
# science              -0.177
# database             0.159
# web                  0.145
# model                -0.143
# big_data             -0.129
# platform             -0.127
# data_scientist       -0.112
# support              0.108
# problem              -0.105
# research             -0.105
# cloud                -0.096
# marketing            0.088
# machine_learning     -0.088
# insight              -0.087
# analyst              -0.087
# algorithm            -0.084
# plan                 0.081
# technique            -0.080
# analytical           -0.079
# visualization        -0.077
# source               -0.074
# strategy             0.071
# set                  -0.071
# python               -0.068
# quality              -0.065
# sql                  -0.064
# market               0.062
# ux                   0.061
# security             0.059
# delivery             0.059
# developer            0.058
# implementation       0.056
# result               -0.056
# mobile               0.055
# knowledge            -0.055
# advanced             -0.054
# infrastructure       -0.052
# complex              -0.051
# analytic             -0.051
# reporting            -0.050
# manage               0.050
# field                -0.049
# test                 -0.049
# pipeline             -0.049
# method               -0.048
# machine              -0.048
# report               -0.046
# professional         0.045
# modeling             -0.045
# need                 0.043
# statistical          -0.043
# issue                0.042
# release              0.042
#
#
# Topic 10
# security             -0.539
# test                 -0.408
# client               -0.281
# program              0.255
# marketing            -0.219
# support              0.171
# information          -0.139
# user                 -0.136
# platform             0.124
# research             -0.121
# infrastructure       0.119
# analysis             -0.107
# manager              0.106
# cloud                0.099
# analytics            -0.096
# qa                   -0.094
# strategy             -0.083
# market               -0.079
# position             0.079
# production           0.078
# operation            0.078
# people               0.073
# testing              -0.066
# employee             0.063
# code                 0.061
# job                  0.060
# aws                  0.057
# delivery             0.056
# deployment           0.054
# building             0.054
# organization         0.053
# devops               0.052
# time                 0.052
# test_case            -0.049
# test_plan            -0.048
# result               -0.048
# leadership           0.047
# analyst              -0.047
# test_automation      -0.046
# web                  -0.046
# insight              -0.045
# automation           -0.044
# center               0.043
# architecture         0.043
# report               -0.039
# professional         0.038
# ’s                   0.037
# digital              -0.037
# change               0.036
# ux                   -0.036
# build                0.036
# year                 0.035
# developer            0.035
# problem              0.034
# world                0.033
# training             0.033
# level                0.032
# quality_assurance    -0.030
# plan                 0.030
# part                 0.030
#
#
# Topic 11
# quality              0.435
# position             -0.345
# marketing            -0.328
# user                 0.325
# web                  -0.285
# program              -0.208
# developer            -0.135
# sale                 0.110
# candidate            -0.104
# employee             -0.101
# java                 -0.092
# manager              0.090
# year                 -0.089
# job                  -0.086
# information          -0.083
# issue                0.083
# partner              0.083
# code                 -0.080
# education            -0.077
# test                 -0.074
# organization         0.070
# ux                   0.069
# qualification        -0.067
# stakeholder          0.066
# risk                 0.066
# security             0.065
# need                 0.063
# or                   -0.060
# delivery             0.060
# standard             0.059
# support              0.058
# practice             0.058
# change               0.056
# database             0.055
# problem              0.055
# benefit              -0.054
# professional         -0.054
# applicant            -0.054
# client               -0.053
# infrastructure       0.051
# goal                 0.051
# operation            0.050
# performance          0.049
# must                 -0.049
# metric               0.047
# control              0.047
# science              -0.046
# role                 0.045
# interaction          0.043
# agency               -0.043
# feature              0.043
# office               -0.042
# computer             -0.042
# improvement          0.042
# employment           -0.042
# production           0.041
# people               0.040
# strategy             0.040
# supplier             0.040
# decision             0.040
#
#
# Topic 12
# support              -0.535
# quality              0.311
# database             0.279
# people               0.202
# user                 -0.200
# security             0.176
# program              0.176
# analysis             -0.152
# employee             0.147
# ’s                   0.126
# world                0.125
# infrastructure       -0.124
# network              -0.112
# research             -0.111
# cloud                -0.109
# marketing            -0.101
# operation            -0.097
# knowledge            -0.091
# deployment           -0.088
# devops               -0.088
# job                  0.086
# industry             0.085
# professional         0.081
# implementation       -0.080
# time                 0.075
# automation           -0.071
# integration          -0.069
# sale                 0.061
# position             0.061
# information          0.061
# career               0.061
# way                  0.060
# issue                -0.058
# production           -0.057
# release              -0.056
# year                 -0.056
# life                 0.055
# documentation        -0.054
# great                0.054
# benefit              0.053
# value                0.051
# part                 0.051
# organization         0.050
# culture              0.048
# hardware             -0.047
# provide              -0.047
# center               -0.045
# configuration        -0.045
# ux                   -0.044
# leader               0.042
# passion              0.041
# client               -0.040
# building             0.039
# mission              0.038
# office               0.038
# operational          -0.037
# communication        -0.037
# or                   -0.036
# test                 -0.035
# risk                 0.035
#
#
# Topic 13
# quality              0.473
# test                 -0.409
# program              -0.372
# web                  0.330
# marketing            0.224
# research             -0.172
# database             -0.142
# user                 -0.133
# support              0.121
# infrastructure       -0.101
# information          0.095
# people               -0.095
# developer            0.094
# knowledge            0.089
# cloud                -0.085
# manager              -0.082
# market               0.078
# code                 0.077
# sale                 -0.075
# standard             0.075
# security             0.072
# network              -0.065
# automation           -0.058
# world                -0.058
# hardware             -0.055
# java                 0.052
# science              -0.052
# analyst              0.052
# year                 0.050
# must                 0.050
# result               -0.049
# ’s                   -0.049
# practice             0.045
# position             0.045
# mobile               0.042
# problem              -0.042
# role                 -0.041
# issue                0.041
# model                -0.040
# complex              -0.040
# content              0.040
# center               -0.038
# documentation        0.038
# department           0.037
# testing              -0.037
# control              0.037
# understanding        0.037
# production           0.036
# organization         -0.036
# supplier             0.035
# plus                 0.035
# operation            -0.034
# data_scientist       -0.034
# line                 0.034
# mission              -0.034
# partner              -0.033
# compliance           0.031
# governance           0.031
# client               -0.031
# activity             0.030
#
#
# Topic 14
# program              -0.501
# web                  -0.355
# position             0.265
# employee             0.191
# sale                 -0.188
# analysis             -0.177
# analytics            -0.176
# market               0.174
# research             0.167
# people               0.162
# ’s                   0.155
# job                  0.133
# network              0.106
# infrastructure       0.097
# world                0.096
# platform             -0.096
# time                 0.095
# manager              -0.094
# developer            -0.088
# center               0.078
# industry             0.077
# architecture         -0.073
# sql                  -0.070
# professional         0.067
# part                 0.065
# marketing            0.063
# complex              -0.063
# global               0.063
# automation           0.060
# risk                 -0.059
# information          0.058
# operation            0.055
# delivery             -0.055
# security             -0.053
# education            0.053
# life                 0.052
# devops               0.051
# agile                -0.051
# reporting            -0.049
# office               0.049
# integration          -0.049
# analyst              -0.049
# big_data             -0.048
# benefit              0.048
# stakeholder          -0.048
# cloud                0.047
# partner              -0.046
# model                -0.044
# java                 -0.044
# individual           0.044
# framework            -0.043
# career               0.042
# mobile               -0.042
# multiple             -0.041
# support              0.041
# test                 0.041
# implementation       -0.041
# applicant            0.040
# year                 -0.040
# knowledge            -0.040
#
#
# Topic 15
# cloud                -0.495
# support              0.371
# research             -0.281
# quality              -0.260
# people               0.215
# user                 -0.167
# position             -0.162
# client               -0.149
# security             0.145
# ’s                   0.144
# infrastructure       -0.142
# program              -0.137
# problem              0.131
# world                0.127
# aws                  -0.116
# devops               -0.110
# marketing            -0.097
# partner              0.097
# automation           -0.087
# analytics            0.086
# test                 0.076
# feature              0.073
# network              0.071
# mobile               0.067
# sale                 -0.060
# ux                   -0.058
# global               0.056
# database             -0.053
# way                  0.052
# practice             -0.051
# performance          0.050
# oracle               -0.049
# value                0.049
# organization         0.049
# issue                0.049
# web                  0.046
# education            -0.046
# financial            0.045
# code                 0.044
# report               -0.044
# mission              0.043
# industry             0.042
# role                 0.042
# consumer             0.041
# manager              0.041
# deployment           -0.040
# standard             -0.038
# devops_engineer      -0.037
# candidate            -0.036
# risk                 0.035
# success              0.035
# model                0.035
# or                   -0.035
# year                 -0.034
# hardware             0.034
# great                0.034
# information          -0.033
# part                 0.033
# group                0.032
# thing                0.032
#
#
# Topic 16
# platform             -0.348
# support              -0.337
# quality              -0.275
# program              -0.270
# knowledge            0.226
# marketing            -0.191
# ’s                   -0.164
# architecture         0.163
# manager              0.161
# strategy             0.155
# client               -0.151
# practice             0.131
# research             -0.123
# level                0.123
# organization         0.113
# agile                0.109
# world                -0.107
# leadership           0.107
# enterprise           0.106
# user                 -0.104
# information          0.100
# delivery             0.100
# complex              0.097
# market               0.093
# need                 0.085
# year                 0.082
# lead                 0.079
# security             -0.078
# implementation       0.077
# senior               0.077
# people               -0.074
# infrastructure       -0.072
# partner              0.069
# understanding        0.068
# production           -0.066
# network              -0.066
# architect            0.064
# role                 0.062
# team_member          0.058
# financial            0.055
# stakeholder          0.055
# google               -0.050
# relationship         0.049
# model                0.049
# industry             0.047
# multiple             0.047
# key                  0.047
# goal                 0.046
# professional         0.046
# mission              -0.045
# methodology          0.044
# report               -0.044
# content              -0.044
# mobile               -0.043
# standard             0.043
# integration          0.042
# plan                 0.042
# risk                 0.042
# devops               0.042
# resource             0.041
#
#
# Topic 17
# platform             0.608
# web                  -0.312
# people               -0.218
# infrastructure       -0.192
# architecture         0.190
# automation           -0.165
# cloud                -0.163
# position             0.150
# devops               -0.121
# integration          0.120
# knowledge            0.119
# aws                  -0.119
# analysis             -0.104
# market               0.102
# analytics            -0.087
# support              -0.086
# implementation       0.085
# feature              0.079
# operation            -0.075
# hardware             0.075
# information          0.074
# employee             -0.069
# role                 -0.067
# ’s                   -0.066
# or                   0.065
# enterprise           0.065
# practice             -0.064
# professional         -0.062
# year                 -0.061
# level                0.060
# organization         -0.059
# standard             0.059
# big_data             0.057
# analyst              -0.057
# deployment           -0.056
# world                -0.055
# client               0.054
# report               -0.050
# build                -0.049
# insight              -0.048
# monitoring           -0.048
# communication        0.047
# qa                   -0.047
# way                  -0.046
# specification        0.045
# devops_engineer      -0.045
# marketing            -0.045
# culture              -0.045
# mobile               0.044
# production           -0.044
# real_time            0.043
# document             0.043
# component            0.043
# architect            0.043
# documentation        0.042
# life                 -0.041
# sql                  -0.040
# health               -0.039
# great                -0.038
# candidate            0.038
#
#
# Topic 18
# network              -0.338
# information          0.314
# research             -0.267
# platform             0.260
# knowledge            -0.232
# analytics            0.195
# cloud                0.168
# industry             -0.159
# problem              -0.147
# analyst              0.144
# market               -0.142
# position             0.133
# partner              0.132
# program              -0.131
# report               0.129
# employee             0.125
# quality              -0.120
# architecture         -0.120
# reporting            0.115
# test                 0.111
# support              0.111
# hardware             -0.107
# science              -0.096
# user                 0.096
# manager              0.096
# client               -0.094
# job                  0.091
# code                 -0.090
# need                 0.083
# complex              -0.073
# center               -0.072
# automation           0.071
# algorithm            -0.070
# field                -0.067
# qa                   0.063
# world                -0.062
# department           0.062
# analysis             -0.057
# marketing            -0.056
# familiarity          -0.055
# understanding        -0.053
# server               -0.053
# performance          -0.052
# technique            -0.051
# networking           -0.051
# method               -0.050
# global               -0.050
# expertise            -0.050
# control              -0.049
# organization         0.048
# database             -0.048
# linux                -0.047
# implementation       -0.047
# stakeholder          0.045
# time                 0.045
# model                -0.042
# advanced             -0.041
# machine_learning     -0.041
# metric               0.040
# component            -0.040
#
#
# Topic 19
# research             0.469
# network              -0.456
# support              0.273
# user                 -0.218
# security             0.169
# infrastructure       -0.157
# market               0.153
# performance          -0.143
# information          -0.137
# marketing            -0.132
# knowledge            -0.120
# science              0.119
# ’s                   -0.119
# center               -0.117
# year                 0.109
# developer            0.106
# manager              0.106
# agile                0.102
# operation            -0.101
# analytics            -0.087
# hardware             -0.081
# platform             0.076
# report               -0.075
# code                 0.067
# networking           -0.066
# standard             -0.065
# digital              -0.064
# mobile               -0.064
# reporting            -0.062
# java                 0.062
# practice             0.061
# analyst              -0.060
# production           0.059
# release              0.057
# communication        -0.055
# database             0.052
# server               -0.052
# content              -0.050
# data_scientist       0.050
# google               -0.050
# architecture         -0.048
# world                -0.048
# devops               0.048
# equipment            -0.047
# organization         0.047
# analysis             -0.047
# senior               0.046
# storage              -0.045
# machine_learning     0.041
# job                  -0.041
# qa                   0.039
# device               -0.039
# computer             -0.038
# method               0.038
# employee             -0.037
# algorithm            0.037
# framework            0.035
# site                 -0.035
# team_member          0.035
# complex              -0.033
#
#
# Topic 20
# analysis             0.379
# analytics            -0.274
# web                  0.262
# marketing            -0.252
# platform             0.246
# market               0.202
# user                 -0.184
# support              -0.179
# performance          0.178
# manager              0.175
# research             0.167
# report               0.151
# network              0.145
# architecture         -0.129
# problem              -0.121
# knowledge            -0.119
# program              -0.117
# quality              -0.116
# financial            0.115
# big_data             -0.111
# science              -0.103
# practice             -0.100
# enterprise           -0.092
# infrastructure       0.092
# analyst              0.085
# operation            0.083
# automation           0.083
# mobile               0.082
# integration          -0.080
# reporting            0.077
# cloud                -0.075
# model                -0.072
# complex              -0.068
# feature              0.058
# professional         -0.056
# standard             -0.056
# issue                0.056
# manage               0.055
# strategy             0.054
# qa                   0.052
# level                -0.052
# plan                 0.051
# data_scientist       -0.051
# role                 -0.050
# risk                 0.050
# center               0.048
# industry             -0.047
# machine_learning     -0.046
# test                 -0.045
# architect            -0.043
# organization         -0.043
# implementation       -0.042
# ux                   -0.042
# expertise            -0.041
# server               0.041
# technique            -0.040
# monitoring           0.040
# job                  -0.040
# line                 0.039
# department           0.039
#
#
# Topic 21
# cloud                0.403
# ’s                   0.279
# automation           -0.221
# web                  0.197
# support              0.185
# infrastructure       -0.183
# architecture         0.170
# production           -0.170
# partner              0.169
# enterprise           0.157
# year                 -0.152
# problem              -0.146
# performance          -0.141
# devops               -0.133
# test                 0.131
# integration          0.125
# analysis             0.124
# marketing            -0.121
# code                 -0.118
# manager              -0.117
# build                -0.116
# release              -0.115
# security             -0.114
# industry             0.114
# operation            -0.107
# market               0.103
# deployment           -0.101
# platform             -0.101
# position             -0.095
# network              0.093
# knowledge            -0.092
# user                 -0.085
# practice             -0.085
# oracle               0.084
# issue                -0.081
# world                0.081
# global               0.075
# monitoring           -0.071
# employee             0.069
# implementation       0.066
# research             0.061
# aws                  -0.057
# pipeline             -0.056
# job                  -0.056
# database             0.055
# building             -0.055
# qa                   -0.053
# provider             0.051
# devops_engineer      -0.051
# sale                 -0.047
# analytics            -0.047
# quality              0.047
# client               -0.046
# time                 -0.045
# leader               0.045
# science              -0.044
# linux                -0.044
# feature              -0.044
# task                 -0.043
# organization         0.041
#
#
# Topic 22
# position             -0.446
# manager              -0.357
# information          0.278
# knowledge            0.244
# analytics            -0.220
# year                 -0.190
# network              -0.176
# people               0.171
# practice             0.157
# marketing            0.146
# platform             0.146
# quality              -0.133
# candidate            -0.129
# code                 0.125
# role                 -0.121
# research             0.104
# science              -0.099
# web                  -0.092
# program              0.091
# employee             0.091
# professional         0.087
# security             -0.087
# feature              -0.079
# automation           0.077
# devops               0.069
# user                 -0.069
# health               0.065
# model                -0.064
# standard             0.060
# data_scientist       -0.059
# or                   0.059
# change               0.059
# report               0.059
# plan                 0.055
# analysis             0.055
# organization         0.054
# healthcare           0.054
# big_data             -0.052
# architecture         0.052
# sale                 0.052
# hardware             -0.048
# operation            -0.047
# qualification        -0.047
# others               0.044
# key                  -0.042
# partner              -0.042
# cloud                -0.042
# community            0.041
# insight              -0.041
# financial            0.040
# oracle               -0.039
# manufacturing        -0.039
# job                  0.038
# field                -0.038
# must                 -0.038
# complex              0.038
# build                0.037
# framework            0.036
# machine_learning     -0.036
# market               -0.036
#
#
# Topic 23
# analysis             -0.375
# research             0.354
# cloud                -0.275
# analytics            0.268
# web                  0.245
# problem              -0.212
# developer            -0.183
# network              0.168
# partner              0.164
# code                 -0.152
# user                 -0.145
# organization         0.133
# automation           0.126
# feature              -0.124
# practice             0.119
# market               -0.114
# year                 -0.109
# people               -0.097
# infrastructure       0.096
# manager              -0.094
# ’s                   0.093
# digital              0.084
# strategy             0.081
# industry             -0.080
# center               0.079
# job                  -0.078
# platform             0.076
# architecture         0.075
# position             0.071
# must                 -0.070
# enterprise           0.067
# delivery             0.064
# client               -0.064
# health               0.063
# security             -0.062
# operation            0.060
# qa                   0.059
# oracle               -0.059
# professional         0.059
# complex              -0.059
# world                -0.057
# healthcare           0.057
# marketing            -0.056
# knowledge            0.056
# performance          0.051
# insight              0.051
# time                 -0.048
# devops               0.047
# specification        -0.046
# information          0.044
# financial            -0.043
# initiative           0.042
# deployment           0.042
# leadership           0.042
# report               -0.041
# big_data             0.041
# great                -0.041
# aws                  -0.041
# science              0.041
# database             0.040
#
#
# Topic 24
# knowledge            -0.430
# problem              0.361
# information          0.268
# year                 -0.232
# web                  0.229
# performance          0.183
# complex              0.171
# automation           -0.148
# analysis             -0.145
# role                 -0.135
# industry             -0.131
# ’s                   -0.130
# plus                 -0.114
# analyst              -0.113
# sql                  -0.104
# qa                   -0.104
# developer            -0.099
# operation            0.097
# program              -0.093
# cloud                0.092
# science              0.092
# user                 -0.087
# financial            -0.084
# or                   0.078
# production           0.077
# reporting            -0.077
# client               0.075
# issue                0.073
# must                 -0.073
# network              -0.072
# infrastructure       0.072
# professional         -0.072
# report               -0.071
# level                0.069
# plan                 0.068
# mobile               -0.068
# test                 0.067
# security             -0.064
# hardware             0.064
# architecture         0.063
# result               0.060
# practice             -0.057
# strategy             0.056
# code                 0.054
# healthcare           -0.053
# global               -0.052
# sale                 0.047
# algorithm            0.047
# standard             0.047
# partner              -0.047
# good                 -0.046
# change               0.046
# others               0.045
# support              -0.044
# benefit              -0.044
# health               -0.044
# review               0.043
# employee             -0.042
# procedure            0.041
# machine_learning     0.040
#
#
# Topic 25
# knowledge            0.429
# cloud                0.255
# architecture         -0.243
# manager              0.233
# ’s                   -0.227
# role                 -0.214
# developer            -0.209
# analysis             -0.204
# analytics            0.200
# partner              -0.184
# web                  0.178
# integration          -0.159
# problem              0.137
# job                  0.118
# platform             0.109
# devops               -0.108
# code                 -0.107
# implementation       -0.102
# network              0.102
# position             -0.100
# people               0.100
# support              0.099
# market               0.099
# industry             0.096
# infrastructure       -0.091
# candidate            -0.089
# enterprise           -0.086
# practice             -0.081
# year                 -0.077
# performance          -0.075
# marketing            -0.075
# must                 0.070
# senior               -0.069
# employee             0.066
# sale                 -0.061
# architect            -0.058
# deployment           -0.055
# report               0.053
# hardware             -0.052
# big_data             0.051
# build                -0.047
# release              -0.047
# lead                 -0.046
# analyst              -0.046
# good                 0.046
# standard             -0.045
# line                 0.045
# level                -0.044
# result               0.044
# automation           -0.042
# qa                   0.040
# agile                -0.038
# science              0.037
# familiarity          -0.037
# success              -0.037
# training             0.036
# test                 0.035
# google               -0.035
# financial            0.034
# user                 -0.033
#
#
# Topic 26
# market               -0.425
# information          -0.304
# industry             -0.272
# manager              0.225
# program              -0.194
# marketing            0.192
# financial            -0.171
# partner              0.166
# global               -0.159
# research             0.146
# people               0.141
# level                0.139
# strategy             -0.132
# user                 -0.130
# network              0.126
# infrastructure       -0.120
# operation            -0.111
# problem              0.108
# analytics            -0.107
# cloud                0.094
# must                 0.089
# automation           -0.088
# job                  0.087
# time                 0.086
# risk                 -0.084
# analysis             0.084
# organization         0.081
# big_data             -0.076
# line                 -0.074
# model                -0.074
# security             0.073
# report               0.073
# world                -0.072
# team_member          0.072
# professional         0.070
# platform             0.067
# knowledge            0.064
# aws                  -0.064
# support              -0.063
# issue                0.063
# complex              0.063
# devops               -0.061
# year                 -0.061
# mobile               -0.056
# staff                0.055
# implementation       0.053
# portfolio            -0.053
# science              -0.052
# code                 0.050
# employee             0.049
# control              -0.048
# production           -0.046
# practice             0.046
# task                 0.045
# opportunity          -0.044
# department           0.044
# build                -0.043
# others               0.042
# analyst              0.041
# feature              0.040
#
#
# Topic 27
# performance          0.373
# information          -0.369
# year                 -0.284
# manager              -0.242
# position             0.240
# network              -0.239
# developer            -0.234
# ’s                   -0.213
# analysis             0.173
# partner              -0.148
# architecture         0.146
# research             -0.127
# problem              -0.119
# security             0.118
# user                 0.115
# professional         0.113
# employee             0.112
# strategy             0.111
# level                0.096
# practice             0.096
# web                  0.091
# support              0.082
# release              -0.080
# code                 -0.080
# science              -0.075
# feature              -0.072
# leadership           0.070
# people               0.068
# healthcare           -0.061
# platform             0.057
# financial            0.057
# knowledge            0.055
# growth               0.054
# qa                   -0.052
# organization         0.051
# java                 -0.049
# analyst              -0.047
# quality              -0.046
# industry             0.044
# database             -0.043
# sql                  -0.042
# google               -0.040
# digital              0.039
# report               -0.038
# communication        -0.038
# or                   -0.038
# internal             -0.038
# ux                   0.037
# health               -0.036
# goal                 0.036
# opportunity          0.036
# center               -0.034
# career               0.034
# key                  0.033
# program              0.033
# time                 0.032
# manage               -0.032
# job                  0.031
# content              -0.031
# oracle               -0.030
#
#
# Topic 28
# year                 -0.420
# role                 0.310
# ’s                   -0.267
# position             0.263
# performance          -0.261
# partner              0.253
# problem              0.225
# analytics            -0.182
# automation           0.155
# knowledge            0.143
# manager              -0.130
# professional         -0.127
# practice             -0.118
# information          0.111
# architecture         -0.107
# standard             -0.104
# industry             -0.101
# qa                   0.100
# plan                 -0.091
# or                   -0.089
# complex              0.088
# quality              0.086
# market               0.084
# program              0.076
# implementation       -0.069
# support              0.066
# big_data             -0.062
# key                  0.061
# employee             -0.060
# test                 -0.060
# must                 -0.060
# code                 -0.060
# database             0.060
# network              0.058
# release              0.057
# issue                0.056
# review               -0.056
# candidate            0.053
# aws                  -0.051
# people               0.051
# job                  -0.051
# analyst              0.050
# enterprise           0.049
# control              -0.049
# activity             -0.049
# goal                 -0.048
# department           -0.047
# feature              0.047
# report               -0.042
# production           -0.042
# analysis             0.042
# education            -0.041
# multiple             0.040
# staff                -0.040
# job_type_full_time   -0.039
# web                  0.039
# way                  0.038
# compliance           -0.038
# equipment            -0.037
# plus                 0.037
#
#
# Topic 29
# ’s                   -0.541
# year                 0.369
# network              0.348
# people               0.282
# knowledge            -0.277
# architecture         0.146
# enterprise           0.132
# operation            -0.118
# information          0.106
# platform             0.091
# quality              0.090
# support              0.090
# strategy             0.085
# production           -0.083
# issue                -0.081
# manager              -0.080
# partner              -0.075
# analysis             0.070
# organization         0.067
# position             -0.064
# developer            -0.064
# job                  0.064
# healthcare           0.063
# release              -0.063
# cloud                -0.059
# science              -0.058
# mobile               0.057
# risk                 -0.054
# employee             0.053
# problem              -0.050
# code                 -0.049
# performance          -0.048
# security             -0.048
# professional         0.048
# control              -0.048
# agile                0.048
# internal             -0.047
# or                   -0.046
# google               -0.045
# aws                  -0.045
# health               0.042
# benefit              0.042
# automation           0.041
# architect            0.040
# life                 0.040
# market               0.040
# networking           0.040
# model                -0.039
# culture              0.037
# group                -0.037
# value                0.036
# manufacturing        -0.036
# community            0.034
# career               0.034
# qa                   0.033
# ...
# analytics            -0.109
# mobile               -0.108
# organization         0.101
# lead                 0.096
# complex              -0.094
# integration          -0.093
# marketing            -0.086
# center               -0.086
# java                 -0.084
# partner              -0.082
# role                 0.081
# platform             0.080
# part                 -0.079
# practice             0.079
# leadership           0.078
# operation            0.069
# multiple             0.069
# communication        0.067
# model                0.066
# ’s                   0.062
# architecture         -0.060
# analysis             -0.059
# research             -0.058
# key                  0.057
# storage              -0.057
# need                 0.057
# server               -0.056
# year                 0.053
# benefit              -0.051
# aws                  -0.050
# information          0.050
# plus                 -0.049
# goal                 0.049
# change               0.049
# stakeholder          0.048
# data_scientist       0.047
# user                 -0.047
# insight              0.044
#
#
# Topic 42
# level                -0.441
# infrastructure       -0.353
# mobile               -0.326
# operation            0.261
# financial            0.177
# architecture         0.166
# partner              0.164
# enterprise           -0.157
# developer            -0.146
# organization         -0.140
# network              0.131
# practice             0.123
# ’s                   -0.121
# time                 0.118
# code                 0.109
# role                 -0.108
# senior               -0.097
# agile                0.096
# integration          0.094
# risk                 0.092
# model                0.088
# report               0.082
# cloud                0.080
# group                0.077
# part                 0.072
# market               -0.071
# industry             -0.069
# analytics            -0.064
# position             0.064
# analysis             -0.061
# automation           0.061
# building             0.060
# reporting            0.059
# professional         -0.058
# feature              0.057
# science              -0.055
# must                 -0.054
# knowledge            -0.054
# control              0.053
# sql                  0.052
# need                 -0.052
# job                  -0.051
# standard             0.050
# consumer             0.048
# complex              -0.048
# server               -0.047
# relevant             -0.047
# finance              0.046
# plus                 0.046
# aws                  0.046
# expert               -0.045
# storage              -0.045
# implementation       0.044
# success              0.043
# problem              -0.043
# quality              -0.042
# office               0.042
# key                  0.042
# education            -0.041
# .                    -0.040
#
#
# Topic 43
# code                 -0.268
# employee             0.263
# architecture         0.246
# developer            0.218
# plan                 0.202
# enterprise           -0.202
# level                -0.199
# financial            -0.183
# aws                  0.171
# organization         -0.158
# agile                -0.153
# practice             -0.151
# automation           0.148
# infrastructure       0.145
# need                 0.143
# candidate            -0.138
# release              -0.135
# benefit              0.131
# knowledge            0.128
# implementation       0.118
# integration          0.118
# problem              0.112
# mobile               -0.108
# understanding        -0.104
# job                  -0.101
# time                 0.099
# risk                 -0.098
# global               -0.094
# network              -0.093
# cloud                -0.091
# hardware             0.091
# group                -0.083
# qa                   0.081
# lead                 0.079
# or                   -0.078
# production           -0.078
# java                 -0.074
# analyst              -0.072
# oracle               -0.072
# world                -0.067
# strategy             0.065
# plus                 -0.064
# performance          -0.061
# analysis             0.061
# leadership           0.059
# digital              -0.057
# vision               0.056
# big_data             0.055
# healthcare           0.055
# health               0.052
# professional         -0.050
# content              -0.048
# activity             0.047
# architect            0.046
# training             0.045
# building             0.044
# familiarity          -0.044
# qualification        -0.043
# analytics            0.043
# issue                -0.042
#
#
# Topic 44
# operation            0.361
# financial            -0.257
# employee             0.255
# model                -0.220
# infrastructure       -0.213
# analytics            0.195
# analysis             0.185
# science              -0.168
# qa                   -0.153
# release              0.151
# agile                0.151
# job                  -0.135
# devops               0.135
# risk                 -0.125
# professional         -0.125
# group                -0.119
# report               -0.117
# problem              0.107
# senior               -0.104
# deployment           0.100
# mobile               0.100
# architecture         -0.100
# year                 0.099
# knowledge            0.094
# practice             0.092
# digital              0.089
# machine_learning     -0.086
# must                 -0.085
# delivery             0.085
# strategy             -0.084
# integration          0.083
# sql                  -0.082
# data_scientist       -0.080
# need                 -0.078
# automation           -0.077
# support              -0.073
# or                   -0.073
# analyst              -0.072
# enterprise           0.071
# issue                -0.071
# area                 -0.070
# organization         0.068
# people               -0.067
# market               0.067
# big_data             -0.066
# test                 0.066
# performance          -0.058
# information          0.057
# developer            -0.056
# document             -0.053
# candidate            0.053
# partner              -0.052
# algorithm            -0.050
# staff                -0.050
# investment           -0.048
# capability           0.048
# production           0.047
# benefit              0.047
# resource             -0.046
# hardware             0.046
#
#
# Topic 45
# or                   0.472
# people               0.284
# mobile               -0.273
# must                 -0.200
# job                  -0.191
# practice             -0.183
# problem              -0.179
# infrastructure       -0.179
# employee             -0.174
# integration          0.151
# level                0.139
# automation           0.124
# candidate            0.120
# model                -0.114
# financial            -0.112
# code                 -0.107
# architecture         -0.103
# test                 -0.103
# hardware             0.100
# digital              -0.099
# standard             -0.099
# user                 0.092
# qa                   0.091
# research             -0.082
# performance          0.082
# familiarity          0.081
# science              0.077
# market               0.077
# professional         0.077
# support              -0.075
# world                0.074
# industry             -0.070
# release              0.070
# analytics            0.070
# mission              0.067
# operation            0.067
# need                 0.063
# developer            0.062
# organization         0.062
# position             -0.059
# consumer             -0.059
# control              0.059
# field                0.056
# risk                 -0.055
# benefit              -0.053
# linux                0.052
# payment              -0.050
# production           -0.049
# time                 -0.048
# education            0.047
# healthcare           0.047
# architect            -0.045
# complex              -0.045
# strategy             -0.044
# analysis             -0.043
# documentation        0.042
# network              -0.041
# program              -0.041
# following            0.041
# feature              -0.040
#
#
# Topic 46
# professional         -0.348
# release              -0.288
# or                   0.274
# implementation       -0.238
# issue                -0.203
# job                  -0.196
# level                0.170
# manager              0.167
# employee             0.161
# developer            -0.158
# people               -0.151
# code                 0.131
# healthcare           0.129
# automation           0.124
# architecture         0.120
# plan                 -0.120
# production           -0.117
# build                -0.111
# deployment           -0.101
# infrastructure       0.095
# enterprise           -0.095
# support              0.094
# health               0.094
# time                 -0.093
# financial            0.093
# senior               0.091
# delivery             -0.088
# practice             0.082
# standard             0.080
# agile                0.078
# manage               -0.078
# analyst              0.078
# analytics            -0.075
# analysis             -0.074
# plus                 0.074
# model                -0.073
# operation            0.072
# complex              0.070
# feature              -0.070
# report               0.067
# content              -0.064
# position             -0.064
# member               0.064
# framework            0.064
# key                  -0.063
# information          -0.063
# communication        -0.061
# change               -0.060
# problem              0.060
# research             -0.053
# staff                0.053
# mobile               0.052
# need                 0.051
# clinical             0.051
# patient              0.049
# medical              0.049
# group                0.048
# client               0.047
# innovation           0.047
# task                 -0.047
#
#
# Topic 47
# job                  -0.380
# operation            -0.359
# feature              -0.232
# employee             0.221
# issue                0.198
# enterprise           -0.195
# financial            0.189
# risk                 0.187
# center               -0.166
# release              0.158
# plan                 0.157
# industry             -0.137
# network              0.125
# agile                0.119
# code                 -0.117
# automation           -0.115
# production           0.115
# digital              0.105
# qa                   -0.102
# group                0.100
# need                 -0.088
# strategy             -0.086
# devops               0.084
# global               0.083
# complex              0.082
# level                0.081
# standard             -0.080
# building             -0.077
# benefit              0.074
# manager              0.071
# report               -0.070
# market               -0.070
# analyst              -0.068
# world                0.065
# position             0.064
# equipment            -0.064
# deployment           0.063
# manage               0.062
# education            -0.061
# part                 0.060
# partner              -0.060
# life                 0.055
# culture              0.054
# big_data             0.054
# program              -0.053
# communication        0.051
# science              0.051
# information          0.049
# build                0.048
# client               -0.047
# research             -0.047
# resource             0.046
# operational          -0.045
# training             -0.044
# performance          -0.043
# member               0.043
# senior               0.043
# familiarity          0.042
# amazon               -0.042
# control              0.042
#
#
# Topic 48
# enterprise           0.275
# model                0.253
# operation            0.239
# or                   -0.207
# science              0.203
# professional         -0.196
# mobile               0.190
# analysis             -0.181
# job                  -0.180
# aws                  -0.172
# analytics            -0.167
# healthcare           0.149
# employee             0.139
# health               0.135
# report               0.132
# integration          0.132
# center               0.131
# automation           -0.128
# role                 -0.121
# partner              -0.117
# release              0.113
# ’s                   -0.107
# implementation       0.105
# analyst              0.103
# code                 -0.103
# developer            0.102
# information          -0.101
# must                 -0.099
# benefit              0.093
# strategy             -0.089
# data_scientist       0.089
# sql                  0.089
# plan                 0.083
# practice             -0.081
# performance          0.078
# complex              -0.074
# network              -0.072
# level                0.072
# database             -0.071
# support              -0.068
# digital              -0.067
# various              0.066
# financial            0.065
# cloud                0.064
# manager              -0.060
# marketing            0.059
# department           0.059
# reporting            0.059
# qa                   0.059
# people               0.058
# global               -0.058
# problem              -0.056
# organization         0.053
# patient              0.053
# medical              0.052
# issue                0.052
# care                 0.051
# control              -0.049
# life                 0.049
# leadership           -0.049
#
#
# Topic 49
# level                0.497
# or                   -0.268
# aws                  0.253
# feature              0.237
# role                 -0.215
# architecture         0.193
# practice             -0.174
# senior               0.154
# standard             -0.148
# problem              -0.146
# infrastructure       -0.139
# operation            0.139
# performance          -0.136
# issue                0.120
# implementation       -0.117
# strategy             0.114
# need                 -0.111
# automation           0.109
# model                -0.101
# mobile               -0.093
# organization         -0.089
# research             0.083
# information          0.083
# code                 0.080
# agile                -0.075
# integration          -0.075
# multiple             0.073
# professional         0.072
# job                  -0.071
# healthcare           -0.070
# production           0.067
# science              -0.067
# analytics            0.066
# market               -0.065
# qa                   0.064
# manager              -0.060
# platform             -0.059
# hardware             0.058
# world                0.056
# analyst              0.054
# health               -0.054
# consumer             0.053
# candidate            -0.052
# risk                 0.052
# technique            -0.051
# .                    0.050
# part                 0.050
# great                0.050
# activity             -0.049
# key                  0.049
# oracle               -0.048
# way                  0.047
# expert               0.045
# delivery             -0.045
# data_scientist       -0.043
# amazon               0.043
# report               0.041
# analysis             -0.041
# member               -0.039
# devops               -0.037
#
#
# Topic 50
# aws                  -0.540
# or                   -0.291
# automation           0.243
# enterprise           -0.232
# code                 0.224
# professional         0.155
# job                  -0.135
# cloud                0.125
# center               0.122
# analytics            0.122
# strategy             -0.120
# implementation       0.103
# understanding        -0.102
# market               0.101
# hardware             0.099
# candidate            -0.087
# organization         0.087
# partner              0.087
# need                 -0.086
# amazon               -0.084
# test                 -0.081
# qa                   0.081
# mobile               -0.081
# global               0.079
# control              0.077
# information          0.075
# oracle               0.073
# network              -0.073
# level                0.072
# year                 0.070
# report               -0.070
# science              0.068
# role                 0.068
# devops               -0.067
# agile                -0.067
# standard             0.067
# healthcare           0.067
# must                 0.064
# industry             -0.061
# .                    -0.061
# analyst              -0.061
# model                -0.061
# time                 -0.061
# staff                0.060
# feature              0.059
# related              0.058
# documentation        0.056
# google               0.055
# goal                 -0.054
# quality              -0.052
# area                 0.051
# issue                -0.049
# sql                  -0.048
# support              -0.048
# digital              -0.047
# analysis             0.047
# amazon_web_service   -0.045
# research             -0.045
# user                 0.045
# expertise            0.043
